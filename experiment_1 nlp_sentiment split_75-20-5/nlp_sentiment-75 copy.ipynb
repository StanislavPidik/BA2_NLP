# %% [markdown]
# # NLP Sentiment Analysis
# 75 - 20 - 5
#
# Source: inspired by https://huggingface.co/, https://www.kaggle.com/

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import time
from IPython import display
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from lime.lime_text import LimeTextExplainer
import warnings
warnings.simplefilter("ignore", category=FutureWarning)
pd.set_option('display.max_colwidth', True)

# %%
CM_FONT_SIZE = 12
LIME_NEG_REVIEW = 5
LIME_POS_REVIEW = 12508
CLASS_NAMES = ['negative(0)','positive(1)']

# %%
import os
from datetime import datetime as dt

OUTPUT_PATH = 'output'
time_str = dt.now().strftime("%H-%M-%S")
date_str = dt.now().strftime("%Y_%m_%d")

if not os.path.exists(f'{OUTPUT_PATH}/{date_str}'):
    os.makedirs(f'{OUTPUT_PATH}/{date_str}')

# %% [markdown]
# # IMDB Dataset

# %%
# import re
# import nltk
# nltk.download('omw-1.4')
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('punkt')
# nltk.download('wordnet')
# stopwords = nltk.corpus.stopwords.words('english')

# %%
# from pywsd.utils import lemmatize_sentence

# %% [markdown]
# Dataset structure:
# ```
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
# })
# ```

# %%
# import datasets
# from datasets import load_dataset

# %%
# The full train and test data, concatenated together.
# data = load_dataset('imdb', split='train+test')

# %%
# data['text'][2]

# %%
# df_imdb = pd.DataFrame(data=data, columns=data.features)
# df_imdb.head()

# %%
# df_imdb.hist();

# %% [markdown]
# # Preprocess data

# %%
# def clean_text (row):

#     cl_text =  row['text'].lower()

#     cl_text = re.sub(r'<.*?>', '', cl_text) # remove HTML tags

#     cl_text = re.sub(r'\d+', '', cl_text)  # remove numbers
   
#     cl_text = cl_text.split()
#     cl_text = [i for i in cl_text if i not in stopwords] # remove stopwords

#     cl_text = [re.sub(r'\W', ' ', s) for s in cl_text]
#     cl_text = ' '.join(cl_text)
  
#     cl_text = lemmatize_sentence(cl_text) # lemmatization
#     cl_text = ' '.join(cl_text)

#     return cl_text

# %%
# df_imdb['review_preproc'] = df_imdb.apply(clean_text, axis=1)

# %%
# df_imdb

# %% [markdown]
# # Store data

# %%
# df_imdb.to_csv('./data_imdb/data_imdb.csv', index=False)

# %% [markdown]
# # Load data
#
# The data are stored locally, it gives us full control over the data and also guarantees that we have the same data for each experiment, the owner of the online data can change it without our knowledge, or even delete it

# %%
data = pd.read_csv('./data_imdb/data_imdb.csv')

# %% [markdown]
# # Visualization of Review Words

# %%
from wordcloud import WordCloud

# %%
np.random.seed(2)
sns.set(rc={'figure.figsize':(16,9)})
reviews_pos = ' '.join(data[data['label']==1]['text'].tolist())

wordcloud_pos = WordCloud(background_color="#f8f8f8", 
                      relative_scaling=1,
                      max_words=60,  
                      min_word_length=3                  
                      ).generate(reviews_pos)
plt.figure()
plt.imshow(wordcloud_pos, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.title('Positive Reviews',size=20, pad=20).set_weight('bold')
plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_positive_reviews.png')
plt.show()

# %%
word_freq_pos = wordcloud_pos.process_text(reviews_pos)
word_freq_list_pos = [(word, freq) for word, freq in word_freq_pos.items()]
word_freq_list_pos = sorted(word_freq_list_pos, key=lambda x: x[1], reverse=True)
print(word_freq_list_pos[:100])
# Out:
# [('film', 35321), ('movie', 33189), ('one', 20150), ('character', 9891), ('time', 9684), ('make', 8806), ('story', 8633), ('see', 8507), ('show', 8276), ('even', 7324), ('way', 7079), ('good', 6962), ('much', 6907), ('great', 6875), ('think', 6813), ('well', 6623), ('people', 6430), ('really', 6295), ('scene', 6260), ('made', 6077), ('love', 5870), ('life', 5722), ('end', 5629), ('know', 5500), ('seen', 5492), ('watch', 5102), ('will', 5053), ('still', 4927), ('many', 4769), ('best', 4747), ('play', 4737), ('look', 4705), ('work', 4537), ('say', 4428), ('thing', 4401), ('take', 4339), ('seem', 4324), ('first', 4322), ('give', 4314), ('man', 4289), ('little', 4275), ('part', 4200), ('now', 4175), ('find', 4100), ('actor', 3859), ('two', 3821), ('come', 3805), ('plot', 3698), ('role', 3690), ('lot', 3620), ('though', 3482), ('something', 3468), ('world', 3431), ('performance', 3427), ('director', 3372), ('fact', 3286), ('serie', 3248), ('feel', 3230), ('better', 3141), ('real', 3110), ('never', 3100), ('want', 3069), ('alway', 3035), ('acting', 3024), ('live', 3023), ('thought', 3004), ('may', 2989), ('back', 2980), ('music', 2948), ('going', 2908), ('actually', 2893), ('although', 2892), ('another', 2867), ('funny', 2843), ('set', 2839), ('especially', 2775), ('day', 2716), ('right', 2689), ('saw', 2680), ('played', 2656), ('family', 2655), ('yet', 2654), ('become', 2648), ('course', 2636), ('fan', 2588), ('friend', 2569), ('new', 2557), ('watching', 2553), ('got', 2452), ('girl', 2449), ('quite', 2446), ('turn', 2424), ('kid', 2402), ('found', 2361), ('tell', 2306), ('guy', 2299), ('bad', 2291), ('bit', 2251), ('probably', 2243), ('rather', 2239)]

# %%
# how many words?
len(word_freq_list_pos)
# Out:
# 96288

# %%
np.random.seed(2)
sns.set(rc={'figure.figsize':(16,9)})
reviews_neg = ' '.join(data[data['label']==0]['text'].tolist())

wordcloud_neg = WordCloud(background_color="#f8f8f8", 
                      relative_scaling=1,
                      max_words=60, 
                      min_word_length=3                   
                      ).generate(reviews_neg)
plt.figure()
plt.imshow(wordcloud_neg, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.title('Negative Reviews',size=20, pad=20).set_weight('bold')
plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_negative_reviews.png')
plt.show()

# %%
word_freq_neg = wordcloud_neg.process_text(reviews_neg)
word_freq_list_neg = [(word, freq) for word, freq in word_freq_neg.items()]
word_freq_list_neg = sorted(word_freq_list_neg, key=lambda x: x[1], reverse=True)
print(word_freq_list_neg[:100])
# Out:
# [('movie', 40573), ('film', 31225), ('one', 20013), ('even', 11160), ('character', 9971), ('make', 8582), ('time', 8306), ('see', 7477), ('story', 7398), ('really', 7254), ('people', 7112), ('bad', 6955), ('good', 6940), ('made', 6891), ('way', 6786), ('scene', 6737), ('think', 6653), ('show', 6636), ('look', 6490), ('know', 6155), ('much', 6063), ('well', 6032), ('end', 5975), ('seem', 5660), ('plot', 5651), ('thing', 5480), ('say', 5395), ('watch', 5356), ('seen', 5281), ('actor', 4729), ('acting', 4673), ('will', 4569), ('director', 4407), ('something', 4229), ('little', 4167), ('take', 4133), ('now', 4086), ('work', 4005), ('first', 3989), ('come', 3882), ('give', 3872), ('still', 3855), ('nothing', 3838), ('going', 3790), ('fact', 3753), ('actually', 3742), ('guy', 3735), ('watching', 3681), ('part', 3657), ('many', 3612), ('two', 3429), ('play', 3412), ('least', 3406), ('find', 3379), ('script', 3372), ('great', 3310), ('man', 3308), ('lot', 3278), ('never', 3272), ('thought', 3263), ('life', 3218), ('want', 3165), ('funny', 3143), ('better', 3137), ('though', 3117), ('point', 3060), ('back', 3027), ('love', 3022), ('girl', 2956), ('got', 2944), ('another', 2801), ('real', 2799), ('original', 2726), ('book', 2698), ('instead', 2693), ('kid', 2666), ('best', 2654), ('start', 2644), ('set', 2639), ('right', 2634), ('mean', 2630), ('maybe', 2627), ('anything', 2619), ('someone', 2610), ('feel', 2585), ('shot', 2574), ('probably', 2539), ('kind', 2496), ('saw', 2494), ('reason', 2480), ('believe', 2467), ('role', 2464), ('minute', 2462), ('rather', 2441), ('anyone', 2418), ('friend', 2411), ('gets', 2409), ('boring', 2407), ('idea', 2389), ('might', 2386)]

# %%
# how many words?
len(word_freq_list_neg)
# Out:
# 91294

# %% [markdown]
# # Train Eval Test Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# (75:25 0.25x0.8=0.2 -> 20%, 0.25x0.2=0.05 => 5%)
#
# train 75. eval 20. test 5

# %%
X_train, X_test, y_train, y_test = train_test_split(data[['text','review_preproc']], 
                                                    data['label'], 
                                                    train_size=0.75, 
                                                    random_state=2)

# %%
# X_train, X_test, y_train, y_test = train_test_split(data[['text','review_preproc']], 
#                                                     data['label'], 
#                                                     train_size=0.09,
#                                                     test_size=0.03,
#                                                     random_state=2)

# %%
# X_test

# %%
# train -> validation
X_eval, X_test, y_eval, y_test = train_test_split(X_test, 
                                                  y_test, 
                                                  train_size=0.8, 
                                                  random_state=2)

# %%
# X_eval

# %%
count_eval_0 = (y_eval==0).sum()
print("eval negative: ",count_eval_0)

count_eval_0 = (y_eval==1).sum()
print("eval positivetive: ",count_eval_0)
# Out:
# eval negative:  4993
# eval positivetive:  5007

# %%
# X_test

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

# %%
tf_idf_vect_nb = TfidfVectorizer(
    max_features=10000 # the 10000 most common words 
    )

tf_idf_train = tf_idf_vect_nb.fit_transform(X_train['review_preproc'].values)
tf_idf_eval = tf_idf_vect_nb.transform(X_eval['review_preproc'].values)

# %%
# tf_idf_train

# %%
# tf_idf_eval

# %% [markdown]
# ### Optimize Hyperparameter Alpha

# %%
alpha_range = list(np.arange(1,10,1))

alpha_scores = []

for a in alpha_range:
    clf = MultinomialNB(alpha=a)
    scores = cross_val_score(clf, tf_idf_train, y_train, cv=5, scoring='accuracy')
    alpha_scores.append(scores.mean())
    print(a,scores.mean())
# Out:
# 1 0.8567199999999999
# 2 0.85656
# 3 0.8567733333333333
# 4 0.8564266666666667
# 5 0.8562933333333334
# 6 0.85616
# 7 0.8561066666666667
# 8 0.8562133333333334
# 9 0.8560000000000001

# %%
MSE = [1 - x for x in alpha_scores] 

optimal_alpha = alpha_range[MSE.index(min(MSE))]

plt.plot(alpha_range, MSE)
plt.xlabel('alpha')
plt.ylabel('MSE')
plt.show()

# %%
print("Optimal alpha: ", optimal_alpha)
# Out:
# Optimal alpha:  3

# %%
clf = MultinomialNB(alpha=optimal_alpha)

# %%
pipe_nb = Pipeline([('vec', tf_idf_vect_nb), ('clf', clf)])
pipe_nb.fit(X_train['review_preproc'].values, y_train)
# Out:
# Pipeline(steps=[('vec', TfidfVectorizer(max_features=10000)),
#                 ('clf', MultinomialNB(alpha=3))])

# %% [markdown]
# ### Evaluate Naive Bayes

# %%
start_time = time.time()

y_pred_eval_nb = pipe_nb.predict(X_eval['review_preproc'].values)

end = time.time()
tm = end - start_time

time_per_sample_nb = tm/len(X_eval)*1000
print("Time per sample: ", time_per_sample_nb, " ms.")
# Out:
# Time per sample:  0.08352744579315186  ms.

# %%
cm_nb = confusion_matrix(y_eval, y_pred_eval_nb)
cm_nb

# [[TN, FP],
#  [FN, TP]]
# Out:
# array([[4275,  718],
#        [ 766, 4241]])

# %%
group_names =  ['True Negative','False Positive','False Negative','True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm_nb.flatten()]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(7,5))

ax = sns.heatmap(cm_nb, annot=labels, fmt='', cmap='Blues', annot_kws={"size": CM_FONT_SIZE+2})

ax.set_title("Confusion Matrix - Naive Bayes", fontsize=CM_FONT_SIZE+2, pad=20).set_weight('bold')

ax.set_xlabel("Predicted", fontsize=CM_FONT_SIZE, labelpad=10)
ax.xaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

ax.set_ylabel("True", fontsize=CM_FONT_SIZE, labelpad=10)
ax.yaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_cm_nb.png')
plt.show()

# %%
naive_bayes_report = classification_report(y_eval, y_pred_eval_nb, output_dict=True)

# %%
naive_bayes_report
# Out:
# {'0': {'precision': 0.8480460226145606,
#   'recall': 0.8561986781494092,
#   'f1-score': 0.8521028503089496,
#   'support': 4993},
#  '1': {'precision': 0.8552127445049406,
#   'recall': 0.8470141801477931,
#   'f1-score': 0.8510937186433876,
#   'support': 5007},
#  'accuracy': 0.8516,
#  'macro avg': {'precision': 0.8516293835597506,
#   'recall': 0.8516064291486012,
#   'f1-score': 0.8515982844761686,
#   'support': 10000},
#  'weighted avg': {'precision': 0.8516344002650738,
#   'recall': 0.8516,
#   'f1-score': 0.8515975780840028,
#   'support': 10000}}

# %%
print(classification_report(y_eval, y_pred_eval_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      4993
#            1       0.86      0.85      0.85      5007
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %% [markdown]
# ### Explain Naive Bayes

# %%
explainer_nb = LimeTextExplainer(class_names=CLASS_NAMES)

exp_nb_neg = explainer_nb.explain_instance(data['review_preproc'][LIME_NEG_REVIEW], pipe_nb.predict_proba, num_features=10)
exp_nb_pos = explainer_nb.explain_instance(data['review_preproc'][LIME_POS_REVIEW], pipe_nb.predict_proba, num_features=10)

# %%
# print("True rating", data['label'][5], "\n")
# exp_nb_neg.show_in_notebook(text=True)

# %%
# print("True rating", data['label'][12508], "\n")
# exp_nb_pos.show_in_notebook(text=True)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
tf_idf_vect_rf = TfidfVectorizer(
    max_features=10000 # the 10000 most common words    
    )

rf = RandomForestClassifier(random_state=2, n_estimators=100)
pipe_rf = Pipeline([('vec', tf_idf_vect_rf), ('rf', rf)])
pipe_rf.fit(X_train['review_preproc'].values, y_train)
# Out:
# Pipeline(steps=[('vec', TfidfVectorizer(max_features=10000)),
#                 ('rf', RandomForestClassifier(random_state=2))])

# %% [markdown]
# ### Evaluate Random Forest

# %%
start_time = time.time()

y_pred_eval_rf = pipe_rf.predict(X_eval['review_preproc'].values)

end = time.time()
tm = end - start_time

time_per_sample_rf = tm/len(X_eval)*1000
print("Time per sample: ", time_per_sample_rf, " ms.")
# Out:
# Time per sample:  0.1271735668182373  ms.

# %%
cm_rf = confusion_matrix(y_eval, y_pred_eval_rf)
cm_rf
# Out:
# array([[4297,  696],
#        [ 879, 4128]])

# %%
group_names =  ['True Negative','False Positive','False Negative','True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm_rf.flatten()]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(7,5))

ax = sns.heatmap(cm_rf, annot=labels, fmt='', cmap='Blues', annot_kws={"size": CM_FONT_SIZE+2})

ax.set_title("Confusion Matrix - Random Forest", fontsize=CM_FONT_SIZE+2, pad=20).set_weight('bold')

ax.set_xlabel("Predicted", fontsize=CM_FONT_SIZE, labelpad=10)
ax.xaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

ax.set_ylabel("True", fontsize=CM_FONT_SIZE, labelpad=10)
ax.yaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_cm_rf.png')
plt.show()

# %%
random_forest_report = classification_report(y_eval, y_pred_eval_rf, output_dict=True)

# %%
random_forest_report
# Out:
# {'0': {'precision': 0.830177743431221,
#   'recall': 0.8606048467854996,
#   'f1-score': 0.8451175140131774,
#   'support': 4993},
#  '1': {'precision': 0.8557213930348259,
#   'recall': 0.8244457759137208,
#   'f1-score': 0.839792493133964,
#   'support': 5007},
#  'accuracy': 0.8425,
#  'macro avg': {'precision': 0.8429495682330235,
#   'recall': 0.8425253113496103,
#   'f1-score': 0.8424550035735707,
#   'support': 10000},
#  'weighted avg': {'precision': 0.8429674487877459,
#   'recall': 0.8425,
#   'f1-score': 0.8424512760589552,
#   'support': 10000}}

# %%
print(classification_report(y_eval, y_pred_eval_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85      4993
#            1       0.86      0.82      0.84      5007
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %% [markdown]
# ### Explain Random Forest

# %%
# input_text_rf = tf_idf_vect_rf.transform([data['review_preproc'][5]])

# %%
# prediction_rf = rf.predict(input_text_rf)

# %%
# prediction_rf

# %%
explainer_rf = LimeTextExplainer(class_names=CLASS_NAMES)

exp_rf_neg = explainer_rf.explain_instance(data['review_preproc'][LIME_NEG_REVIEW], pipe_rf.predict_proba, num_features=10)
exp_rf_pos = explainer_rf.explain_instance(data['review_preproc'][LIME_POS_REVIEW], pipe_rf.predict_proba, num_features=10)

# %%
# print("True rating", data['label'][5], "\n")
# exp_rf_neg.show_in_notebook(text=True)

# %%
# print("True rating", data['label'][12508], "\n")
# exp_rf_pos.show_in_notebook(text=True)

# %% [markdown]
# #  Long Short-Term Memory (LSTM)

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout, SpatialDropout1D

# %%
top_words = 10000
max_review_length = 256
embedding_vecor_length = 32

tokenizer_lstm = Tokenizer(num_words=top_words)
# prepare data for training
tokenizer_lstm.fit_on_texts(X_train['review_preproc'])
list_tokenized_train = tokenizer_lstm.texts_to_sequences(X_train['review_preproc'])
X_train_lstm = pad_sequences(list_tokenized_train, maxlen=max_review_length)
# prepare data for evaluation
x_eval_tok = tokenizer_lstm.texts_to_sequences(X_eval['review_preproc'])
x_eval_tok_pad = pad_sequences(x_eval_tok, maxlen=max_review_length)

# %%
model_lstm = load_model('./lstm_model/2023-04-18_19-08-10_model_lstm_08.h5')

# %% [markdown]
# ### Evaluate LSTM

# %%
start_time = time.time()

y_pred_eval_lstm_float = model_lstm.predict(x_eval_tok_pad)

end = time.time()
tm = end - start_time

time_per_sample_lstm = tm/len(X_eval)*1000
print("Time per sample: ", time_per_sample_lstm, " ms.")
# Out:
# Time per sample:  1.6553798913955688  ms.

# %%
# y_pred_eval_lstm = (y_pred_eval_lstm > 0.5).astype(np.float32)
y_pred_eval_lstm = (y_pred_eval_lstm_float > 0.5).astype(np.int32).ravel()

# %%
cm_lstm = confusion_matrix(y_eval, y_pred_eval_lstm)
cm_lstm
# Out:
# array([[4392,  601],
#        [ 632, 4375]])

# %%
group_names =  ['True Negative','False Positive','False Negative','True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm_lstm.flatten()]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(7,5))

ax = sns.heatmap(cm_lstm, annot=labels, fmt='', cmap='Blues', annot_kws={"size": CM_FONT_SIZE+2})

ax.set_title("Confusion Matrix - LSTM", fontsize=CM_FONT_SIZE+2, pad=20).set_weight('bold')

ax.set_xlabel("Predicted", fontsize=CM_FONT_SIZE, labelpad=10)
ax.xaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

ax.set_ylabel("True", fontsize=CM_FONT_SIZE, labelpad=10)
ax.yaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_cm_lstm.png')
plt.show()

# %%
lstm_report = classification_report(y_eval, y_pred_eval_lstm, output_dict=True)

# %%
lstm_report
# Out:
# {'0': {'precision': 0.8742038216560509,
#   'recall': 0.8796314840777087,
#   'f1-score': 0.8769092542677448,
#   'support': 4993},
#  '1': {'precision': 0.8792202572347267,
#   'recall': 0.8737767126023567,
#   'f1-score': 0.8764900330561955,
#   'support': 5007},
#  'accuracy': 0.8767,
#  'macro avg': {'precision': 0.8767120394453889,
#   'recall': 0.8767040983400327,
#   'f1-score': 0.8766996436619702,
#   'support': 10000},
#  'weighted avg': {'precision': 0.876715550950294,
#   'recall': 0.8767,
#   'f1-score': 0.876699350207122,
#   'support': 10000}}

# %%
print(classification_report(y_eval, y_pred_eval_lstm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      4993
#            1       0.88      0.87      0.88      5007
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %% [markdown]
# ### Explain LSTM

# %%
def predict_proba(arr):
    processed = []
    for i in arr:
        processed.append(i)

    list_tokenized_ex = tokenizer_lstm.texts_to_sequences(processed)
    Ex = pad_sequences(list_tokenized_ex, maxlen=max_review_length)
    pred = model_lstm.predict(Ex)
    returnable = []
    for i in pred:
        temp = i[0]
        returnable.append(np.array([1-temp, temp]))
    return np.array(returnable)

# %%
explainer_lstm = LimeTextExplainer(class_names=CLASS_NAMES)

exp_lstm_neg = explainer_lstm.explain_instance(data['review_preproc'][LIME_NEG_REVIEW], predict_proba)
exp_lstm_pos = explainer_lstm.explain_instance(data['review_preproc'][LIME_POS_REVIEW], predict_proba)

# %%
# print("True rating", data['label'][LIME_NEG_REVIEW], "\n")
# exp_lstm_neg.show_in_notebook(text=True)

# %%
# print("True rating", data['label'][LIME_POS_REVIEW], "\n")
# exp_lstm_pos.show_in_notebook(text=True)

# %% [markdown]
# # Transformers_general  - "off the shelf"
# ### General tuned: sst-2-english, HuggingFace

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
# Load the model
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
tokenizer_tr_gen = AutoTokenizer.from_pretrained(model_name)
model_tr_gen = AutoModelForSequenceClassification.from_pretrained(model_name)

# %%
# Predict function
def predict_fn_gen(texts):
    inputs = tokenizer_tr_gen(texts, padding=True, 
                           truncation=True, return_tensors="pt")
    outputs = model_tr_gen(**inputs)
    predictions = torch.softmax(outputs.logits, dim=1).detach().numpy()
    return predictions

# %% [markdown]
# ## Evaluate Transformer_general - "off the shelf"

# %%
# import time
# start_time = time.time()

# softmax_predictions_tr_gen = predict_fn_gen(list(X_eval['text'].values))
# y_pred_eval_tr_gen = np.argmax(softmax_predictions_tr1, axis=1)

# end = time.time()
# tm = end - start_time

# time_per_sample_transformer_gen = tm/len(X_eval)*1000
# print("Time per sample: ", time_per_sample_transformer_gen, " ms.")

# %%
y_pred_eval_tr_gen = []

import time
start_time = time.time()

for chunk in np.array_split(X_eval, 1000):

    softmax_predictions_tr_gen_chunk = predict_fn_gen(list(chunk['text'].values))
    predictions_tr_gen_chunk = np.argmax(softmax_predictions_tr_gen_chunk, axis=1)
    y_pred_eval_tr_gen.extend(predictions_tr_gen_chunk)

end = time.time()
tm = end - start_time

time_per_sample_transformer_gen = tm/len(X_eval)*1000
print("Time per sample: ", time_per_sample_transformer_gen, " ms.")
# Out:
# Time per sample:  97.4926383972168  ms.

# %%
cm_tr_gen = confusion_matrix(y_eval, y_pred_eval_tr_gen)  # confusion_matrix(y_true, y_pred)
cm_tr_gen
# Out:
# array([[4609,  384],
#        [ 692, 4315]])

# %%
group_names =  ['True Negative','False Positive','False Negative','True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm_tr_gen.flatten()]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(7,5))

ax = sns.heatmap(cm_tr_gen, annot=labels, fmt='', cmap='Blues', annot_kws={"size": CM_FONT_SIZE+2})

ax.set_title("Confusion Matrix - Transformer - general", fontsize=CM_FONT_SIZE+2, pad=20).set_weight('bold')

ax.set_xlabel("Predicted", fontsize=CM_FONT_SIZE, labelpad=10)
ax.xaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

ax.set_ylabel("True", fontsize=CM_FONT_SIZE, labelpad=10)
ax.yaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_cm_tr1.png')
plt.show()

# %%
transformer_gen_report = classification_report(y_eval, y_pred_eval_tr_gen, output_dict=True)

# %%
transformer_gen_report
# Out:
# {'0': {'precision': 0.869458592718355,
#   'recall': 0.9230923292609654,
#   'f1-score': 0.8954730911210415,
#   'support': 4993},
#  '1': {'precision': 0.918280485209619,
#   'recall': 0.8617934891152387,
#   'f1-score': 0.8891407376880279,
#   'support': 5007},
#  'accuracy': 0.8924,
#  'macro avg': {'precision': 0.893869538963987,
#   'recall': 0.8924429091881021,
#   'f1-score': 0.8923069144045347,
#   'support': 10000},
#  'weighted avg': {'precision': 0.8939037142887309,
#   'recall': 0.8924,
#   'f1-score': 0.8923024817571317,
#   'support': 10000}}

# %%
print(classification_report(y_eval, y_pred_eval_tr_gen))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      4993
#            1       0.92      0.86      0.89      5007
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %% [markdown]
# ## Explain Transformer_1 - "off the shelf"

# %%
explainer_tr_gen = LimeTextExplainer(class_names=CLASS_NAMES)

exp_tr_gen_neg = explainer_tr_gen.explain_instance(data['text'][LIME_NEG_REVIEW], predict_fn_gen, num_samples=10)
exp_tr_gen_pos = explainer_tr_gen.explain_instance(data['text'][LIME_POS_REVIEW], predict_fn_gen, num_samples=10)

# %%
# print("True rating", data['label'][LIME_NEG_REVIEW],"\n")
# exp_tr_gen_neg.show_in_notebook(text=True)

# %%
# print("True rating", data['label'][LIME_POS_REVIEW],"\n")
# exp_tr_gen_pos.show_in_notebook(text=True)

# %%
# The top 10 contributing words for the positive prediction
print("Top contributing words for the positive prediction:")
print(exp_tr_gen_neg.as_list(label=1))
# Out:
# Top contributing words for the positive prediction:
# [('ones', -0.02486253062636029), ('my', 0.009352389500392867), ('films', 0.008590095565765858), ('people', -0.00399674736808151), ('night', 0.001832098837182669), ('scenes', 0.0017041040138505562), ('angle', 0.0017041040138505562), ('controversial', 0.001704104013850556), ('you', -0.00019055325514821594), ('sophomore', -0.00019055325514821578)]

# %% [markdown]
# ## Transformer fine tuned on IMDB Data Set

# %%
from transformers import TFDistilBertForSequenceClassification
import tensorflow as tf

# %%
from transformers import DistilBertTokenizerFast
tokenizer_tr_tuned = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

# %%
model_tr_tuned = TFDistilBertForSequenceClassification.from_pretrained("./distilbert_fine_tuned_6")
# Out:
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at ./distilbert_fine_tuned_6.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %% [markdown]
# ### Evaluate Transformer fine tuned

# %%
def predict_fn_tuned(texts):
    inputs = tokenizer_tr_tuned(texts, padding=True, truncation=True, return_tensors='tf')
#     print(inputs)
    outputs = model_tr_tuned(**inputs)
    predictions = tf.nn.softmax(outputs.logits).numpy()
    predictions_labels = tf.math.argmax(predictions, axis=1).numpy()
    return predictions

# %%
# start_time = time.time()

# softmax_predictions_tr_tuned = predict_fn_tuned(list(X_eval['text'].values))
# y_pred_eval_tr_tuned = np.argmax(softmax_predictions_tr_tuned, axis=1)

# end = time.time()
# tm = end - start_time

# time_per_sample_transformer_tuned = tm/len(X_eval)*1000
# print("Time per sample: ", time_per_sample_transformer_tuned, " ms.")

# %%
y_pred_eval_tr_tuned = []

import time
start_time = time.time()

for chunk in np.array_split(X_eval, 1000):
    softmax_predictions_tr_tuned_chunk = predict_fn_tuned(list(chunk['text'].values))
    predictions_tr_tuned_chunk = np.argmax(softmax_predictions_tr_tuned_chunk, axis=1)
    y_pred_eval_tr_tuned.extend(predictions_tr_tuned_chunk)

end = time.time()
tm = end - start_time

time_per_sample_transformer_tuned = tm/len(X_eval)*1000
print("Time per sample: ", time_per_sample_transformer_tuned, " ms.")
# Out:
# Time per sample:  174.138134598732  ms.

# %%
cm_tr_tuned = confusion_matrix(y_eval, y_pred_eval_tr_tuned)
cm_tr_tuned
# Out:
# array([[4628,  365],
#        [ 275, 4732]])

# %%
group_names =  ['True Negative','False Positive','False Negative','True Positive']
group_counts = ["{0:0.0f}".format(value) for value in cm_tr_tuned.flatten()]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(7,5))

ax = sns.heatmap(cm_tr_tuned, annot=labels, fmt='', cmap='Blues', annot_kws={"size": CM_FONT_SIZE+2})

ax.set_title("Confusion Matrix - Transformer - Fine Tuned (IMDB)", fontsize=CM_FONT_SIZE+2, pad=20).set_weight('bold')

ax.set_xlabel("Predicted", fontsize=CM_FONT_SIZE, labelpad=10)
ax.xaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

ax.set_ylabel("True", fontsize=CM_FONT_SIZE, labelpad=10)
ax.yaxis.set_ticklabels(['Negative', 'Positive'], fontsize=CM_FONT_SIZE)

plt.savefig(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_cm_tr_tuned.png')
plt.show()

# %%
transformer_tuned_report = classification_report(y_eval, y_pred_eval_tr_tuned, output_dict=True)

# %%
transformer_tuned_report
# Out:
# {'0': {'precision': 0.943911890679176,
#   'recall': 0.9268976567194072,
#   'f1-score': 0.935327405012126,
#   'support': 4993},
#  '1': {'precision': 0.9283892485775946,
#   'recall': 0.945076892350709,
#   'f1-score': 0.9366587490102929,
#   'support': 5007},
#  'accuracy': 0.936,
#  'macro avg': {'precision': 0.9361505696283854,
#   'recall': 0.9359872745350581,
#   'f1-score': 0.9359930770112095,
#   'support': 10000},
#  'weighted avg': {'precision': 0.9361397037789142,
#   'recall': 0.936,
#   'f1-score': 0.9359940089520081,
#   'support': 10000}}

# %%
print(classification_report(y_eval, y_pred_eval_tr_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      4993
#            1       0.93      0.95      0.94      5007
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %% [markdown]
# ### Explain Transformer fine tuned

# %%
explainer_tr_tuned = LimeTextExplainer(class_names=CLASS_NAMES)

exp_tr_tuned_neg = explainer_tr_tuned.explain_instance(data['text'][LIME_NEG_REVIEW], predict_fn_tuned, num_samples=10)
exp_tr_tuned_pos = explainer_tr_tuned.explain_instance(data['text'][LIME_POS_REVIEW], predict_fn_tuned, num_samples=10)

# %%
# print("True rating", data['label'][LIME_NEG_REVIEW],"\n")
# exp_tr_tuned_neg.show_in_notebook(text=True)

# %%
# print("True rating", data['label'][LIME_POS_REVIEW],"\n")
# exp_tr_tuned_pos.show_in_notebook(text=True)

# %% [markdown]
# ## Final Repport

# %%
dfs = []

df = pd.DataFrame()
for key, value in naive_bayes_report.items():
    if type(value) != dict:
        df.loc[0, key] = value
    else:
        for nested_key, nested_value in value.items():
            column_name = f"{key}_{nested_key}" 
            df.loc[0, column_name] = nested_value
df['time ms'] = time_per_sample_nb
df['model'] = "Naive Bayes"
dfs.append(df)

df = pd.DataFrame()
for key, value in random_forest_report.items():
    if type(value) != dict:
        df.loc[0, key] = value
    else:
        for nested_key, nested_value in value.items():
            column_name = f"{key}_{nested_key}" 
            df.loc[0, column_name] = nested_value
df['time ms']=time_per_sample_rf
df['model']="Random Forest"
dfs.append(df)


df = pd.DataFrame()
for key, value in lstm_report.items():
    if type(value) != dict:
        df.loc[0, key] = value
    else:
        for nested_key, nested_value in value.items():
            column_name = f"{key}_{nested_key}" 
            df.loc[0, column_name] = nested_value
df['time ms'] = time_per_sample_lstm
df['model'] = "LSTM"
dfs.append(df)

df = pd.DataFrame()
for key, value in transformer_gen_report.items():
    if type(value) != dict:
        df.loc[0, key] = value
    else:
        for nested_key, nested_value in value.items():
            column_name = f"{key}_{nested_key}" 
            df.loc[0, column_name]=nested_value
df['time ms'] = time_per_sample_transformer_gen
df['model'] = "Transformer general"
dfs.append(df)


df = pd.DataFrame()
for key, value in transformer_tuned_report.items():
    if type(value) != dict:
        df.loc[0, key] = value
    else:
        for nested_key, nested_value in value.items():
            column_name = f"{key}_{nested_key}" 
            df.loc[0, column_name]=nested_value
df['time ms'] = time_per_sample_transformer_tuned
df['model'] = "Transformer tuned"
dfs.append(df)

final_report = pd.concat(dfs, ignore_index=True)

# %%
final_report
# Out:
#    0_precision  0_recall  0_f1-score  0_support  1_precision  1_recall  \
# 0  0.848046     0.856199  0.852103    4993.0     0.855213     0.847014
# 1  0.830178     0.860605  0.845118    4993.0     0.855721     0.824446
# 2  0.874204     0.879631  0.876909    4993.0     0.879220     0.873777
# 3  0.869459     0.923092  0.895473    4993.0     0.918280     0.861793
# 4  0.943912     0.926898  0.935327    4993.0     0.928389     0.945077
#
#    1_f1-score  1_support  accuracy  macro avg_precision  macro avg_recall  \
# 0  0.851094    5007.0     0.8516    0.851629             0.851606
# 1  0.839792    5007.0     0.8425    0.842950             0.842525
# 2  0.876490    5007.0     0.8767    0.876712             0.876704
# 3  0.889141    5007.0     0.8924    0.893870             0.892443
# 4  0.936659    5007.0     0.9360    0.936151             0.935987
#
#    macro avg_f1-score  macro avg_support  weighted avg_precision  \
# 0  0.851598            10000.0            0.851634
# 1  0.842455            10000.0            0.842967
# 2  0.876700            10000.0            0.876716
# 3  0.892307            10000.0            0.893904
# 4  0.935993            10000.0            0.936140
#
#    weighted avg_recall  weighted avg_f1-score  weighted avg_support  \
# 0  0.8516               0.851598               10000.0
# 1  0.8425               0.842451               10000.0
# 2  0.8767               0.876699               10000.0
# 3  0.8924               0.892302               10000.0
# 4  0.9360               0.935994               10000.0
#
#       time ms                model
# 0  0.083527    Naive Bayes
# 1  0.127174    Random Forest
# 2  1.655380    LSTM
# 3  97.492638   Transformer general
# 4  174.138135  Transformer tuned

# %%
# save final report as csv
final_report.to_csv(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_final_report.csv', index=False)

# %%
# final_report=pd.read_csv('./output/_final_report.csv')

# %%
# save final report as exel
final_report.to_excel(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_final_report.xlsx', index=False)

# %%
final_report = final_report.round(2)

# %%
fig = px.scatter(final_report, x="model", y=["0_precision",
                                      "1_precision",
                                      "0_recall",
                                      "1_recall",
                                      "0_f1-score",
                                      "1_f1-score",
                                      "accuracy"
                                      ], text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_final_all_scat.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.scatter(final_report, x="model", y=["weighted avg_precision",
                                      
                                      "weighted avg_recall",
                                     
                                      "weighted avg_f1-score",
                                      
                                      "accuracy"
                                      ], text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_final_all_avg_scat.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.bar(final_report, x="model", y=["0_precision",
                                      "1_precision",
                                      "0_recall",
                                      "1_recall",
                                      "0_f1-score",
                                      "1_f1-score",
                                      "accuracy"], 
                                      barmode='group',
                                      text_auto='')
fig.update_yaxes(range=[0.75, 0.99])
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_final_all_bar.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.bar(final_report, x="model", y=["weighted avg_precision",
                                         "weighted avg_recall",
                                         "weighted avg_f1-score",
                                         "accuracy"], 
                                      barmode='group',
                                      text_auto='')
fig.update_yaxes(range=[0.75, 0.99])
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_final_all_avg_bar.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.scatter(final_report, x="model", y=["0_precision",
                                             "1_precision",
                                            ], text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_precision.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.scatter(final_report, x="model", y=["0_recall",
                                            "1_recall",
                                            ], text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_recall.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.scatter(final_report, x="model", y=["0_f1-score",
                                             "1_f1-score"
                                            ], text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_f1_score.png' 
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
# fig=px.scatter(final_report, x="model", y=["0_f1-score",
fig = px.bar(final_report, x="model", y=["0_f1-score",
                                             "1_f1-score"],
                                              barmode='group',
                                               text_auto=''
                                              )#.update_traces(textposition="top right")
path=f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_f1_score.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.scatter(final_report, x="model", y=["accuracy"], text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_accuracy.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %%
fig = px.scatter(final_report, x="model", y=["time ms"], log_y=True, text="value").update_traces(textposition="top right")
path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_time.png'
fig.write_image(path, scale=2)
# fig.show()
display.Image(path)

# %% [markdown]
# ## LIME compare

# %%
data_eval = pd.DataFrame({'eval_true': y_eval, 
                          'NB': y_pred_eval_nb, 
                          'RF': y_pred_eval_rf,
                          'LSTM': y_pred_eval_lstm,
                          'Trans_general': y_pred_eval_tr_gen,
                          'Trans_tuned': y_pred_eval_tr_tuned                        
                           })

path = f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_data_eval.csv'
data_eval.to_csv(path)
# path = './output/2023_xx_xx/xxxx_data_eval.csv'
# data_eval = pd.read_csv(path, index_col=0)

# %%
# data_eval

# %%
# data['text'][LIME_NEG_REVIEW]

# %%
# data['review_preproc'][LIME_NEG_REVIEW]

# %%
# data['text'][LIME_POS_REVIEW]

# %%
# data['review_preproc'][LIME_POS_REVIEW]

# %% [markdown]
# ### negative

# %%
filtered_data_neg = data_eval.loc[(data_eval['eval_true'] == 0) 
                            & (data_eval['NB'] == 1)
                            & (data_eval['RF'] == 1)
                            & (data_eval['LSTM'] == 1) 
                            & (data_eval['Trans_general'] == 1) 
                            & (data_eval['Trans_tuned'] == 1)
                           ]

# %%
filtered_data_neg.shape[0]
# Out:
# 50

# %%
# review_list_neg=filtered_data_neg.head(50).index.tolist()

# %%
review_list_neg = [27295, 4235, 2887, 29795, 5690, 26108, 11611, 31696, 32664, 34014, 1944, 7297, 34219, 6225, 4126, 3457, 9813, 33014, 11668, 3618, 34509]

# %%
# data_eval.loc[review_list_neg]

# %%
for i in review_list_neg:
    print("============================================================================================================\n")
    print("============================================================================================================\n")
    
    print("index:", i, "\n")
    print("True rating", data['label'][i], "\n")
    
    print("Naive Beyes\n")
    exp_nb_neg = explainer_nb.explain_instance(data['review_preproc'][i], pipe_nb.predict_proba, num_features=10);
#     exp_nb_neg.show_in_notebook(text=True)
    exp_nb_neg.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_neg_{i}_nb.html')
    print("Top contributing words for this prediction:")
    print(exp_nb_neg.as_list(label=1))
    
    print("\nRandom Forest\n")
    exp_rf_neg = explainer_rf.explain_instance(data['review_preproc'][i], pipe_rf.predict_proba, num_features=10)
#     exp_rf_neg.show_in_notebook(text=True)
    exp_rf_neg.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_neg_{i}_rf.html')
    print("Top contributing words for this prediction:")
    print(exp_rf_neg.as_list(label=1))
    
    print("\nLSTM\n")
    exp_lstm_neg = explainer_lstm.explain_instance(data['review_preproc'][i], predict_proba)
#     exp_lstm_neg.show_in_notebook(text=True)
    exp_lstm_neg.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_neg_{i}_lstm.html')
    print("Top contributing words for this prediction:")
    print(exp_lstm_neg.as_list(label=1))
    
    print("\nTransformer_genetal - off the shelf\n")
    exp_tr_gen_neg = explainer_tr_gen.explain_instance(data['text'][i], predict_fn_gen, num_samples=10)
#     exp_tr_gen_neg.show_in_notebook(text=True)
    exp_tr_gen_neg.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_neg_{i}_tr_gen.html')
    print("Top contributing words for this prediction:")
    print(exp_tr_gen_neg.as_list(label=1))
    
    print("\nTransformer tuned\n")
    exp_tr_tuned_neg = explainer_tr_tuned.explain_instance(data['text'][i], predict_fn_tuned, num_samples=10)
#     exp_tr_tuned_neg.show_in_notebook(text=True)
    exp_tr_tuned_neg.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_neg_{i}_tr_tuned.html')
    print("Top contributing words for this prediction:")
    print(exp_tr_tuned_neg.as_list(label=1))
    print("\n")
# Out:
# ============================================================================================================
#
# ============================================================================================================
#
# index: 27295
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('insipid', -0.04498686876080722), ('painful', -0.04111118291856348), ('dud', -0.03945946737936605), ('poor', -0.03379799707282401), ('annoy', -0.03291252859711024), ('urban', 0.024345828828353455), ('bad', -0.023798173619956293), ('beautiful', 0.022504111122106808), ('stereotype', -0.020229968344567487), ('homosexuality', 0.01757198126591947)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bad', -0.1080899882310128), ('annoy', -0.05427805001264652), ('poor', -0.05085776477114748), ('painful', -0.04206172237603304), ('minute', -0.040480332201377596), ('either', -0.035717193310337195), ('even', -0.02550396741875872), ('something', -0.02389784395520895), ('beautiful', 0.021447592576283002), ('still', 0.01372784679911754)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('annoy', -0.04030438793920731), ('insipid', -0.03542142767562679), ('stereotype', -0.034259242920938675), ('hilariously', 0.027583237504485658), ('dud', -0.02664344185032773), ('still', 0.023740417356844953), ('bad', -0.02362893399850412), ('poor', -0.023376145511957946), ('care', -0.020680272255528147), ('painful', -0.017966337899605465)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('were', -0.0013154711272037355), ('if', -0.0013154711272037353), ('care', -0.0009420309528712996), ('off', -0.0009420309528712991), ('even', -0.0008549078120536823), ('entire', -0.0008549078120536821), ('scenes', -0.0006334867316153236), ('then', -0.0005927104828509036), ('s', -0.00026004655728288786), ('who', -0.0002600465572828878)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('to', -0.05530718650012783), ('off', -0.03546101238534638), ('were', -0.035461012385346366), ('all', -0.03546101238534636), ('perhaps', -0.03546101238534636), ('still', -0.03546101238534636), ('Irish', -0.03315457697801263), ('renting', -0.03315457697801263), ('if', -0.01696728803456112), ('20', -0.0008593777565131662)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 4235
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('weak', -0.07957690687349706), ('horrendous', -0.04231135273557824), ('terrible', -0.04135064666551233), ('bad', -0.03934338536370597), ('brilliant', 0.03417311921545035), ('musician', 0.03272075554071475), ('dismiss', 0.02880227481217449), ('minute', -0.028693174191582994), ('beautiful', 0.0247730395638278), ('fail', -0.022899116981065823)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('terrible', -0.10056599333555905), ('bad', -0.09980249742313714), ('brilliant', 0.055739814944802596), ('great', 0.04303210360183896), ('script', -0.041125730822240046), ('minute', -0.03669813784068283), ('weak', -0.035573578560768704), ('act', -0.030448178553738728), ('love', 0.030264626106703323), ('hilarious', 0.01997893944995325)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('weak', -0.13793106419097761), ('bad', -0.1137715787865497), ('brilliant', 0.08077277566124386), ('fail', -0.07686516270932375), ('act', -0.059283210012619575), ('original', -0.05707592671961257), ('hilarious', 0.056739464167095056), ('terrible', -0.05519700581368065), ('horrendous', -0.047818090890731406), ('minute', -0.0441692038720164)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('Tokyo', -0.315282779224281), ('see', -0.2613558410251997), ('if', -0.14358872683153545), ('overall', -0.10866326061051607), ('minutes', -0.1082793264223279), ('Drift', -0.1014808594117615), ('comes', 0.09398810265638505), ('there', 0.051880235236610964), ('it', -0.03774003755986605), ('The', 0.004751764048095992)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('Way', -0.10360368958655228), ('Slevin', -0.10360368958655226), ('would', -0.10360368958655224), ('could', -0.10360368958655224), ('As', -0.06286838993035472), ('bad', -0.06286838993035468), ('after', -0.05892965669367672), ('say', 0.052082182417722916), ('prison', -0.049941746352379204), ('see', -0.04994174635237918)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 2887
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('bad', -0.06056353395063386), ('dumb', -0.046133960575207474), ('whoever', -0.03541647532279826), ('capitalize', -0.03489748652162497), ('capture', 0.032068111486325296), ('oscar', 0.02805918679567261), ('nothing', -0.025915166892353042), ('winner', 0.023832431114671586), ('pay', -0.023198022406119772), ('no', -0.021083138462749933)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bad', -0.09446155601176957), ('plot', -0.05983287531021618), ('even', -0.059794870960044835), ('nothing', -0.05718686336100792), ('act', -0.03814834295922049), ('make', -0.033078201153269794), ('dumb', -0.029074558012887473), ('capture', 0.026077443542634977), ('movie', -0.019841854627401116), ('year', 0.016947902884128827)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('capitalize', -0.09797959836182916), ('bad', -0.09670122302872952), ('this', -0.0721027252876635), ('nothing', -0.05068674658642784), ('capture', 0.04876307919378346), ('absolutely', -0.043734965899829364), ('compare', 0.030141488268995025), ('dumb', -0.02887467543289818), ('light', 0.020114887214665523), ('like', 0.01639137100070003)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('defense', -0.0009156461270733977), ('nothing', -0.0004755391767682935), ('looked', -0.0004755391767682935), ('seen', 0.00036318033622709586), ('of', -0.0002502355735907348), ('s', 0.00010352536314762385), ('thriller', 8.707248842212849e-05), ('hope', 6.799006131631307e-05), ('quickly', 4.223134385570214e-05), ('plot', -7.039942344784614e-06)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('movie', -0.008123747365556436), ('dumber', -0.006842282596472656), ('s', -0.006223393304686813), ('part', -0.0034433545535102928), ('even', -0.0031249713498924716), ('worst', -0.0015430004926406677), ('a', 0.001367129318672164), ('about', 0.0013671293186721632), ('In', 0.00046920026430690933), ('ve', 0.00046920026430690906)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 29795
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('yawn', -0.01745697733452799), ('blah', -0.01672713535811357), ('lousy', -0.016008834687916567), ('laughably', -0.015124224329237206), ('whatsoever', -0.014546895960015514), ('uninspired', -0.014358822457044517), ('insult', -0.01389755454618677), ('dull', -0.012924920568634039), ('tedium', -0.011504001213683047), ('junk', -0.010974874299081491)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('dull', -0.07725586863154998), ('ridiculous', -0.07178549723099197), ('fail', -0.041388265252162965), ('nothing', -0.03783218812900105), ('lousy', -0.029236293465951534), ('love', 0.02521571112335936), ('even', -0.02288898336545064), ('script', -0.02085142676452719), ('insult', -0.020851170216263756), ('show', 0.0075728207439102035)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('yawn', -0.0022325828730516127), ('dud', -0.0020446126627192474), ('drag', -0.0016694748932648724), ('lousy', -0.00166310358389833), ('dull', -0.0016338242606557841), ('tedium', -0.001574759580272003), ('innocent', 0.0006505955021114837), ('likewise', 0.0004954546556854428), ('direction', 0.00029384017822851557), ('complete', 0.00019034819257931468)]
#
# Transformer_genetal - off the shelf
# Top contributing words for this prediction:
# [('prison', -0.0009356963045024936), ('relief', -0.0006266483581636342), ('throughout', -0.0006266483581636338), ('finds', 0.0005753592607573359), ('abundant', 0.0005296237105687888), ('in', -0.0003582947669493891), ('needs', -0.0003582947669493889), ('excited', -0.00035765130935441547), ('laughably', -0.00031255921676084204), ('Helga', -0.00017940969755841796)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('sequence', -0.0009547115638108591), ('love', -0.000954711563810859), ('offers', -0.0004097006674554069), ('don', -0.00036342558987029514), ('impress', -0.00036342558987029514), ('dull', -0.0002802365026004963), ('a', 0.00018158530648515714), ('finds', -7.882621739117016e-05), ('overly', -2.168515956626818e-05), ('escape', -2.1685159566268097e-05)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 5690
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('poorly', -0.03547708838643777), ('dreadful', -0.03391610415243962), ('tripe', -0.02837868071934896), ('rubbish', -0.02745974882557069), ('ashamed', -0.02654999236948819), ('appal', -0.02634882224782129), ('amaze', 0.024768723423831705), ('ridiculous', -0.02352365642832486), ('senseless', -0.017365155136568874), ('rewrite', -0.01661333156055781)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('poorly', -0.12941564729095756), ('ridiculous', -0.09820377681283345), ('amaze', 0.0673644663118502), ('dreadful', -0.060082508754883794), ('rubbish', -0.05450253240842221), ('great', 0.05380452685096002), ('money', -0.03323095197491706), ('performance', 0.02676065398654604), ('recommend', 0.022854385233079023), ('world', 0.018710815320381862)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('poorly', -0.014575773283426905), ('rewrite', -0.014118870449914176), ('rubbish', -0.01365544964274994), ('ridiculous', -0.013266538749402089), ('great', 0.012192384851701968), ('invent', -0.010806239553940746), ('senseless', -0.01029466088673433), ('amaze', 0.009368378592930958), ('recover', -0.008640484012760716), ('continue', 0.0075092815004777855)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('ever', -0.1528784590661789), ('Cage', 0.06827594569308702), ('of', -0.062352244511493564), ('spent', 0.049093410252862096), ('is', 0.016619947856846125), ('only', 0.009517221996921158), ('a', 0.009517221996921156), ('dreadful', 0.009517221996921156), ('inaccurate', 0.009517221996921154), ('ridiculous', 0.009517221996921153)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('performance', -0.060013438682348555), ('rubbish', -0.04391100498471312), ('so', -0.03757345847164014), ('Its', -0.034476421360925345), ('have', 0.0283029334896989), ('recent', -0.02813887484785238), ('proves', 0.0218919881586526), ('can', -0.021620373040415187), ('appalling', -0.018935304507240895), ('amazing', 0.009507982441761079)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 26108
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('afterward', 0.07137389776291483), ('waste', -0.07084863263590702), ('pretentious', -0.05448766865003021), ('stupid', -0.04750381755756467), ('explanation', -0.03762216750116371), ('bad', -0.032151736146464945), ('touch', 0.0314441803492338), ('don', -0.021003926208544653), ('sick', -0.016839522474562944), ('issue', 0.01443865417830828)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('waste', -0.12600695834382714), ('bad', -0.12252819310388023), ('touch', 0.08701378854157991), ('stupid', -0.06339045265421063), ('pretentious', -0.025416366387761333), ('feel', 0.025111225350730466), ('movie', -0.02105109312794672), ('see', 0.015442132924407331), ('can', -0.010620245789360766), ('come', 0.008896090159616609)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('waste', -0.08407728623183966), ('pretentious', -0.06319316290398465), ('bad', -0.047391700127544324), ('touch', 0.02848334362264629), ('stupid', -0.02680916833554894), ('soulless', -0.025952558647081195), ('english', 0.02220123577482952), ('care', -0.016440204602192827), ('don', -0.016004076965432372), ('now', 0.013745417699934747)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('with', -0.000641870078622531), ('believe', -0.0004197739513296172), ('demand', -0.00041977395132961705), ('doesn', -0.00034947973934058076), ('are', -0.00018380569070402378), ('All', -0.00012738361204766674), ('back', 0.00010858464857792667), ('wasted', -6.25942581335837e-05), ('the', 4.56833191463108e-05), ('better', 8.367275257726058e-06)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('movie', -0.10969392585801485), ('way', -0.08875474106729911), ('people', -0.05837026858588819), ('in', -0.05340765171703183), ('explanation', -0.053407651717031816), ('t', 0.05109251280287501), ('up', -0.05081230723633609), ('their', -0.05081230723633606), ('seeing', -0.050812307236336056), ('since', -0.021681679295757938)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 11611
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('mstk', -0.07926653968470015), ('waste', -0.05880540061928217), ('dull', -0.04083182802301778), ('skull', -0.03900530286163324), ('zero', -0.03869690989847164), ('favorite', 0.03310921716598503), ('castle', 0.0273204019616172), ('oh', -0.023604543847517253), ('luscious', 0.02358616939295113), ('inheritance', 0.020125964709004306)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('favorite', 0.14449874166519594), ('waste', -0.14192046663834662), ('dull', -0.08021408413954717), ('oh', -0.03903476050050175), ('too', 0.028947271407652044), ('here', 0.021074501205608488), ('movie', -0.021011268620524996), ('interest', -0.01522875843882553), ('zero', -0.011769095152073613), ('try', -0.01081021910867373)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('waste', -0.03784782219009545), ('mstk', -0.03354670591451303), ('oh', -0.02813327735264027), ('dull', -0.026376001791080114), ('favorite', 0.024442682293485937), ('luscious', 0.023813877210667876), ('zero', -0.02052008869974428), ('skull', -0.019073558171217624), ('aristocrat', -0.01797316063928687), ('here', -0.01349410476350353)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('aristocrats', -0.0009852716363509208), ('zero', -0.0008798485652142256), ('Oh', -0.0008384360801684835), ('type', 0.0006369217236042636), ('Skull', 0.0006369217236042636), ('dull', -0.0006311332159135507), ('The', -0.0003777217286440719), ('inheritance', 0.0001203843688792564), ('an', 0.00012038436887925636), ('and', -6.786367234892301e-05)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('those', -0.014677110964283068), ('Evelyn', -0.013945270538308104), ('hell', -0.0139452705383081), ('you', -0.013945270538308099), ('inheritance', -0.010446637189635068), ('here', -0.007317111349602681), ('by', 0.007058635117261124), ('favorite', 0.0043089052464393525), ('Erika', -0.000418889410681659), ('too', -0.00041888941068165853)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 31696
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('redeem', -0.056398005612456045), ('worse', -0.054270707188824964), ('bond', 0.05291758222533155), ('dull', -0.04331929633227481), ('trash', -0.037297299631565264), ('total', -0.02246050375004692), ('bad', -0.021759923852345674), ('god', -0.021658448992461152), ('save', -0.021152801006747893), ('nothing', -0.012962045355725529)]
#
# Random Forest
# Top contributing words for this prediction:
# [('bad', -0.10844762315474665), ('dull', -0.06667451091776382), ('save', -0.05510354658183936), ('nothing', -0.04203935915408592), ('redeem', -0.02603746064039142), ('trash', -0.02489149287778578), ('may', 0.022327359678393666), ('theme', 0.020504949805718504), ('story', 0.019217332323118723), ('god', -0.0162908934622987)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('nothing', -0.022556611866389617), ('bad', -0.02009232756110605), ('dull', -0.01939083619943003), ('redeem', -0.018093970590651536), ('total', -0.01614776811808412), ('bond', 0.015610173155186218), ('see', 0.014379527032436902), ('save', -0.013968603171422811), ('seeing', -0.01341794498782363), ('god', -0.011202046061858087)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('of', -0.09747035020861576), ('was', -0.06710932372375561), ('James', 0.05368824071443493), ('actually', 0.047073351267824255), ('it', 0.0205136898145591), ('seen', 0.020513689814559092), ('is', 0.020513689814559085), ('one', 0.0031559959044542875), ('totally', 0.0031559959044542875), ('whatever', 0.0031559959044542853)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('about', -0.007548288891918569), ('James', -0.007548288891918569), ('actually', -0.006960426106386763), ('any', 0.006139137851516488), ('seen', -0.0046727541380141), ('save', -0.004672754138014097), ('80', 0.003918290195187873), ('in', -0.003197973545361928), ('piece', -0.0031979735453619273), ('It', -0.0031979735453619273)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 32664
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('awful', -0.05598447205365219), ('horrible', -0.050535355606913634), ('excuse', -0.0389271279303875), ('poor', -0.03089951943279668), ('critic', 0.026802243778986233), ('doesn', -0.026628402002519626), ('bad', -0.02293139606506663), ('favor', -0.022639700547556086), ('work', 0.02199369709369031), ('appreciate', 0.021509549757397165)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bad', -0.08955941853325362), ('awful', -0.0806827984068858), ('horrible', -0.06694149807541189), ('poor', -0.05589771539574959), ('well', 0.03368389872101922), ('appreciate', 0.027348502882486025), ('can', -0.02455492431280258), ('make', -0.020316711923847507), ('walk', -0.02017580702254384), ('would', -0.018613409095470396)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('awful', -0.029586232705928063), ('doesn', -0.029051705804007833), ('horrible', -0.026663221033167837), ('poor', -0.01941571816642903), ('appreciate', 0.018004359006372452), ('bad', -0.017597978016099598), ('another', -0.015182143335987247), ('favor', -0.014519769958925413), ('would', -0.010348713827641942), ('director', -0.009193999433302541)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('though', -0.007736951207296279), ('Times', -0.006803496205699168), ('walking', -0.0054419766305929965), ('know', -0.005202008461781887), ('take', -0.004658059361072508), ('certainly', 0.004388605219188814), ('break', 0.004388605219188814), ('together', 0.0020439648083763473), ('critics', 0.0017399838764780792), ('makes', 0.0017399838764780788)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('horrible', -0.03491091323658266), ('makes', -0.03491091323658264), ('won', -0.03491091323658264), ('Producer', -0.03491091323658263), ('worked', -0.026116725238236656), ('budgets', -0.02517109391093642), ('make', -0.02252971113463773), ('smaller', -0.022529711134637722), ('as', -0.01055241561569882), ('me', 0.008526995093616417)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 34014
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('seagal', -0.10235912597724368), ('bad', -0.029954942050118713), ('guy', -0.017751052923922303), ('voodoo', -0.017162270362232553), ('guess', -0.014330343189060221), ('accent', -0.013176487058983156), ('cartoonish', -0.012684273282620161), ('drug', 0.008932355237149884), ('family', 0.004373594730089505), ('niece', 0.0037459998626273713)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bad', -0.11392560026675663), ('favorite', 0.051067853273265316), ('suppose', -0.036966596053720394), ('also', 0.022589466666302), ('anything', -0.021496576570502305), ('guess', -0.021402383660821103), ('even', -0.01908251165584576), ('poor', -0.019033796304364), ('movie', -0.018957912197918526), ('would', -0.010352618216915379)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('seagal', -0.042314643192360786), ('definitely', 0.023748638156617614), ('guess', -0.01948841783972596), ('bad', -0.01895020727465862), ('voodoo', -0.018538544227566463), ('paper', -0.013608801202930959), ('surprise', 0.013002645210581308), ('spit', -0.011399123120380814), ('s', 0.006476233531023056), ('impressive', 0.004687069643506912)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('players', -0.0007703197766639909), ('majority', -0.0007703197766639907), ('not', -0.0007703197766639906), ('goes', -0.0007529865856845563), ('much', -0.0006699962655496669), ('suppose', -0.00023872645483997835), ('set', -0.00015698152866634932), ('raised', 8.069279798100222e-05), ('important', 5.508748468008003e-05), ('weird', -2.5880840551580416e-05)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('was', 0.1107324976127298), ('kids', 0.10110810659863269), ('goofball', 0.08214927231580829), ('calling', 0.07083669296017828), ('cursed', 0.04734641774361097), ('to', 0.03497637787087917), ('broad', 0.0324940313583083), ('re', -0.02414762371724204), ('Marked', 0.012615655752369496), ('mouthfuls', 0.005242212508399958)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 1944
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('retard', -0.03817707114781294), ('ignorant', -0.03518983325863135), ('solid', 0.030361771068042918), ('save', -0.02957625133533486), ('spit', -0.028349843031642945), ('interpret', 0.028076748874179085), ('misguide', -0.027316683132051368), ('heart', 0.02286066509945832), ('gay', -0.02280991673990679), ('realism', 0.019253972948351763)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('save', -0.13224440123310324), ('instead', -0.11274182851151857), ('act', -0.07584463216484033), ('even', -0.059112343293188985), ('make', -0.05599066904555129), ('heart', 0.030059026331523738), ('someone', -0.028391344029455368), ('say', -0.02535284190762212), ('obviously', -0.02503867218925369), ('best', 0.016465599769123717)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('spit', -0.1511691807301761), ('interpret', 0.11574039600232318), ('instead', -0.11480311546560365), ('obviously', -0.09497822491478795), ('solid', 0.08705834474845246), ('catch', 0.06879423954081598), ('save', -0.06849112452774202), ('assumption', -0.0666826344902624), ('slow', -0.06664174136515401), ('bitch', -0.05491813847990677)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('act', 0.09314532095600854), ('help', 0.09314532095600851), ('as', 0.09133796125521584), ('army', 0.08770812186666586), ('was', 0.08390374426755658), ('seriously', 0.08390374426755653), ('some', 0.08390374426755651), ('off', 0.08390374426755651), ('someone', 0.07203984740831997), ('friend', 0.07203984740831991)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('helped', 0.05117321719085405), ('heart', -0.03691424326843692), ('t', 0.028505122466751825), ('friend', -0.02175447085584419), ('realism', 0.018875243107152304), ('person', 0.014334988785642086), ('is', -0.01415713941499757), ('his', -0.005222576957277339), ('set', -0.00334897615631421), ('If', 0.0022253164377750117)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 7297
#
# True rating 0
#
# Naive Beyes
# Top contributing words for this prediction:
# [('disjoint', -0.07431368669791286), ('rivet', 0.04914636769727877), ('camera', -0.03967511414692383), ('scantily', -0.036129771649712344), ('charming', 0.03597480372244178), ('confuse', -0.034425153763069385), ('specially', 0.025891267448611633), ('genuine', 0.02550091660066466), ('nevertheless', 0.025109869275924387), ('movement', 0.024440823133920066)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('plot', -0.08550332546847657), ('guess', -0.05728940359576073), ('dvd', 0.05294851018245858), ('could', -0.0360088914886074), ('confuse', -0.03597614719746702), ('well', 0.024808909684440696), ('movie', 0.02470160301460558), ('still', 0.023939578993464192), ('camera', -0.018500245709134343), ('interest', -0.014076079852676043)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('rivet', 0.3420369733625867), ('guess', -0.29353301383768676), ('disjoint', -0.2776188030843172), ('confuse', -0.2563877362566665), ('genuine', 0.19959816813500475), ('dvd', 0.1700942244582848), ('jerky', -0.16031988807990125), ('entertain', 0.13980560616478313), ('keep', 0.13425017416129886), ('nevertheless', 0.10945085827796001)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('The', 0.13997915797671157), ('ladies', 0.1253188320347339), ('charming', 0.08808255285908563), ('quality', 0.0868284731855884), ('which', 0.08682847318558837), ('nice', 0.07612338297664974), ('could', -0.06639023452178605), ('riveting', 0.057317212186434846), ('a', 0.0017842737489640764), ('the', 0.0017842737489640762)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('few', 0.0008535104933252762), ('plot', 0.0007083247469414084), ('movie', 0.0007083247469414084), ('could', 0.0006079148482104569), ('jerky', 0.0006079148482104569), ('disjointed', 0.00047963183650631685), ('think', 0.0004360871992179036), ('riveting', 0.00029192215661974806), ('end', 0.00029192215661974806), ('get', 6.322924618465754e-05)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 34219
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('boring', -0.058788682710647376), ('jordan', 0.05309818959049785), ('bore', -0.04352263135425317), ('hyper', 0.04326707655249126), ('annoyed', -0.036745695754116486), ('eddie', 0.035804267292404685), ('predictable', -0.03501456272125201), ('definitely', 0.03281226976802042), ('seriously', -0.016851978907569926), ('shoot', -0.014384890247703865)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bore', -0.1526716855288056), ('boring', -0.11268418528203696), ('love', 0.10252914262720945), ('enjoy', 0.05924810086211758), ('predictable', -0.04616687362044622), ('actually', -0.02339793128401864), ('either', -0.01693580356282116), ('shoot', -0.014048102446671923), ('seriously', -0.012537614464768747), ('rest', -0.011909440157650194)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('boring', -0.3799615649645148), ('bore', -0.30761628443780115), ('predictable', -0.25128180797001076), ('rest', -0.20158997923062982), ('it', 0.19235546201781387), ('notice', 0.1885661721939036), ('enjoy', 0.17374048723307065), ('hyper', 0.16680707786082727), ('definitely', 0.1507826855099531), ('mistake', -0.13603074438271445)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('hyper', 0.14583401931057496), ('told', 0.1411480052016649), ('y', 0.13488863716562974), ('but', 0.10160058615406106), ('and', 0.10019322318810638), ('then', 0.09393385515207124), ('definitely', 0.08413073391490984), ('did', 0.05475654886530177), ('either', 0.0420133394569167), ('some', 0.01424899095079094)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('predictable', 0.16337922604461613), ('was', 0.1314974493601465), ('noticed', 0.13141006431340288), ('y', 0.12482239927489927), ('definitely', 0.10092665676176392), ('so', -0.07176952728366508), ('br', -0.06886546422786832), ('boring', -0.04787378477052965), ('s', -0.044969721714732895), ('film', -0.03838205667622948)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 6225
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('helen', 0.021633943092922485), ('perfectly', 0.02073146114131348), ('love', 0.02055134154319635), ('eyre', 0.0203444068938049), ('york', 0.019855887420505237), ('rochester', -0.013696937237651776), ('badly', -0.007871202669624882), ('redeem', -0.007778792065400808), ('script', -0.007573879072881737), ('sentence', -0.0056661363172861275)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('rochester', 0.07936803597326261), ('jane', 0.07195736176429991), ('bad', -0.07056608340490932), ('love', 0.06074223673936874), ('touch', 0.05013460168139092), ('script', -0.04188886639766149), ('badly', -0.040352646514127746), ('even', -0.039261174453798287), ('redeem', -0.03537789183209654), ('perfectly', 0.03369404592674923)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('rational', -0.06055098973224385), ('mildly', -0.03970181690483119), ('jane', -0.038324237230760956), ('script', -0.03796070385595833), ('redeem', -0.03669172804389753), ('compare', 0.03146381485252543), ('perfectly', 0.030902050319582652), ('love', 0.026688401757716633), ('adaptation', -0.026620377828171386), ('miscast', -0.02218373160236061)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('into', -0.0022447104213482428), ('can', -0.002162597354937167), ('have', -0.0012392657300652843), ('often', -0.001195701266188404), ('development', -0.001157152663654207), ('TV', -0.0011571526636542065), ('suffer', -0.0008044310201273983), ('around', -0.0007223179537163211), ('marrying', -0.0006267845112143998), ('I', -0.0005882359086802048)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('5', -0.08989820147733818), ('original', -0.08989820147733817), ('described', -0.08989820147733815), ('various', -0.08989820147733815), ('speak', -0.01297251556399292), ('adopt', -0.012972515563992919), ('in', -0.012972515563992919), ('around', -0.012972515563992919), ('driven', -0.012972515563992917), ('In', -0.012972515563992915)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 4126
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('script', -0.04760090404309637), ('pretentious', -0.0430358465928469), ('paul', 0.03348525406231928), ('han', 0.030356001256717658), ('exceptional', 0.027695344972905083), ('love', 0.023280800553565892), ('mother', 0.02296327832723317), ('journey', 0.021829877280379745), ('german', 0.020504598642324113), ('embarrass', -0.018218265104436436)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('embarrass', -0.06765776451251021), ('great', 0.05544205870426513), ('perfect', 0.048472205110235), ('also', 0.04255748211333619), ('script', -0.04152692875907228), ('love', 0.03784791487146179), ('pretentious', -0.03198747307727044), ('always', 0.029751224849287557), ('would', -0.023123946494189314), ('predictable', -0.018676972684770858)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('script', -0.27468308566088434), ('perfect', 0.27176006920128726), ('pretentious', -0.2627501813343335), ('exceptional', 0.26218382936113427), ('akin', 0.2425282006161433), ('great', 0.1900836262050308), ('pill', -0.1524688142264705), ('would', -0.1257185005680407), ('director', -0.09621599155069875), ('christian', -0.085888816628712)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('arrives', -0.18291183835386612), ('become', -0.14472959965776677), ('nose', 0.03295958515730902), ('courage', 0.030247867907858574), ('Pianist', 0.027130742733419238), ('swallow', 0.027130742733419234), ('son', 0.01931755589954074), ('Wind', 0.019317555899540734), ('a', -0.013479441622567607), ('that', -0.013479441622567588)]
#
# Transformer tuned
# Top contributing words for this prediction:
# [('good', -0.008730409246643686), ('script', -0.008730409246643686), ('completely', -0.008730409246643686), ('Haberland', -0.008730409246643684), ('film', -0.008730409246643684), ('pretentious', -0.008730409246643683), ('something', -0.008578620569359265), ('for', -0.008559289938436989), ('Here', 0.00748138279752534), ('The', 0.003122134070845336)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 3457
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('champion', 0.05438088073639197), ('love', 0.052329952609450094), ('amaze', 0.03344419392192554), ('asleep', -0.03245894338468366), ('strength', 0.03017450176824309), ('today', 0.028526860972196935), ('unless', -0.026598189881183655), ('skip', -0.02573522778644037), ('shameless', -0.02328988598842653), ('miraculously', -0.020900386930301926)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('love', 0.09525514093707659), ('today', 0.0477877858094803), ('amaze', 0.04394037347081564), ('unless', -0.040954019099499674), ('skip', -0.03779284977982899), ('make', -0.031079008483436796), ('actually', -0.027986944050673333), ('even', -0.027823808724296708), ('no', -0.02694993050517972), ('look', -0.020665471162522122)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('skip', -0.5063892148235601), ('unless', -0.2093839491098087), ('shameless', -0.18807641193044106), ('time', 0.1568041963821774), ('love', 0.14762253572470768), ('could', -0.13310880736986108), ('today', 0.1230066801969079), ('amaze', 0.11551364268086405), ('film', 0.11288780182298971), ('champion', 0.0978276927718172)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('time', -0.1143408445854708), ('with', -0.09530047400492501), ('Although', -0.09530047400492501), ('of', -0.0789891690744961), ('watching', -0.07431910281111147), ('him', 0.06107243159550274), ('One', -0.04724075478570055), ('very', -0.047240754785700535), ('This', -0.042744295073968784), ('amazing', 0.01822796917689497)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('boxer', -0.06558752090993912), ('flirting', -0.06558752090993912), ('corner', -0.06558752090993912), ('up', -0.06558752090993912), ('Hitch', -0.0655875209099391), ('loves', -0.06558752090993909), ('overtly', -0.06558752090993909), ('s', -0.06558752090993908), ('movie', -0.06558752090993908), ('No', -0.06558752090993904)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 9813
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('pile', -0.07498905436522196), ('grey', 0.037488116534733405), ('eric', 0.024009527577548945), ('record', 0.023139529276790576), ('manager', 0.0230513841438302), ('great', 0.02269216918317823), ('happy', 0.021934016391190317), ('dialogue', -0.0205518345664868), ('best', 0.020074346347190512), ('els', -0.015742361017136372)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('great', 0.0804580221057535), ('even', -0.05244142314755906), ('best', 0.03825901662232474), ('pile', -0.03264526366647829), ('far', -0.03196945402667179), ('els', -0.02963474070383746), ('dialogue', -0.025761362044072696), ('pose', -0.021320526043559957), ('worth', -0.01802614401475176), ('good', 0.00996139290936623)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('author', -0.28851381876349447), ('saccharine', -0.18123216288730437), ('great', 0.17553777943551657), ('grey', -0.162305900922997), ('feature', -0.15001776397519118), ('record', 0.1156410121477166), ('style', 0.0986336441754518), ('eric', 0.09561820861529703), ('quite', 0.08710104365489911), ('best', 0.07412823794901326)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('posing', -0.30508986104822416), ('in', -0.11211324127621426), ('ending', 0.08169714774342055), ('big', 0.08116368275173548), ('1989', -0.07817791680494493), ('so', 0.07775447123183123), ('that', 0.06863223144272347), ('out', 0.06863223144272347), ('Miller', -0.055236411494168185), ('everyone', -0.014133359806478889)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('dialogue', -0.14916261492160618), ('acting', -0.14681650835721632), ('style', -0.1463309406370341), ('it', -0.1230117108769058), ('and', -0.12301171087690571), ('version', -0.1230117108769057), ('schmaltzy', -0.1140560337247599), ('Stoltz', -0.0652312272476425), ('recorded', -0.043416960962741384), ('lot', 0.028741538386334923)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 33014
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('capture', 0.05442482047781027), ('money', -0.04666001521951672), ('genius', 0.044217875483318604), ('dollar', -0.03843031859869102), ('innocent', 0.03511916454643883), ('except', -0.032481294875557704), ('experience', 0.029042362194518872), ('love', 0.028999484087337962), ('reason', -0.020342506922468497), ('profit', -0.014883063681899126)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('money', -0.19950785839999344), ('reason', -0.06784937944258557), ('love', 0.06313328346147741), ('except', -0.05085318489370734), ('dollar', -0.04657599211781336), ('make', -0.03887908491233762), ('edison', 0.023218042900939508), ('experience', 0.020528122213942988), ('show', 0.018561341067640895), ('life', 0.016620226190813905)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('innocent', 0.24611387353155945), ('dollar', -0.14618297066994015), ('capture', 0.1215341846202756), ('love', 0.11391242344585473), ('money', -0.11378047684346475), ('experience', 0.11367809910646788), ('elephant', 0.10632845746467981), ('except', -0.06865521369372135), ('life', 0.06172973256733784), ('thomas', 0.05961144344195051)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('man', 0.12299252050407578), ('electrocution', 0.08708110569122682), ('was', 0.08578732609462053), ('had', -0.07595816367595008), ('out', -0.07595816367595008), ('can', -0.07466438407934373), ('no', 0.06333571471079716), ('innocent', 0.03721122207669189), ('genius', -0.015848733332993508), ('Thomas', -0.0012877519293695977)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('love', 0.13643950072242486), ('and', 0.1364395007224248), ('Thomas', 0.12123011151979078), ('Edison', 0.10352291313120501), ('the', 0.08745171000338002), ('except', 0.08218309166420698), ('elephant', -0.06399025983296708), ('capture', 0.04536016722782846), ('but', -0.022026746303512), ('dollars', -0.014472734386419404)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 11668
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('great', 0.09316913590507442), ('love', 0.08051265163151167), ('arnold', -0.058156924860093225), ('movie', -0.03292975782644061), ('deep', 0.03155330604293803), ('best', 0.02918334594443901), ('pretty', -0.021619538284769948), ('series', 0.020745245692202197), ('too', 0.015150756685388456), ('thing', -0.014763496569541774)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('thing', -0.1006314920545925), ('best', -0.09815544555305658), ('great', -0.07969094301045784), ('love', -0.07246948103666079), ('pretty', -0.05926196508681809), ('finally', -0.056145500144550525), ('movie', -0.053222293492032606), ('secret', -0.049767240551982596), ('tv', -0.038781311265060174), ('deep', -0.0359888508728828)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('great', 0.050370566526880683), ('love', 0.04559548070266346), ('best', 0.032163073907422235), ('movie', 0.024263357187296716), ('too', 0.021961047385789648), ('thing', 0.015156644150710604), ('funny', 0.015093758836893597), ('series', 0.014066366969870233), ('deep', 0.01366243371804163), ('pretty', 0.01333333407668536)]
#
# Transformer_genetal - off the shelf
# Top contributing words for this prediction:
# [('One', 0.04905221203999792), ('Doy', 0.049052212039997906), ('loved', 0.0490522120399979), ('her', 0.030887348909734453), ('in', 0.030887348909734443), ('it', 0.01872177973107742), ('Arnold', 0.01790792340815646), ('so', -0.016310267433302814), ('that', -0.01614783876213808), ('It', -0.01530387291419014)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('tv', 0.005155921241002095), ('admits', 0.005155921241002094), ('loved', 0.004491858850976022), ('It', 0.00427148880211705), ('s', 0.0035647664613294196), ('i', -0.002692562362416855), ('darkest', 0.0023439593060160697), ('finally', 0.0021843532945267593), ('and', -0.0014315487681833654), ('funny', -0.0010917791467552212)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 3618
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('excellent', 0.08991055152823235), ('exception', -0.03847780495285518), ('concept', -0.030585134675760937), ('different', 0.02959707646129978), ('fun', 0.028200481942503727), ('horror', -0.024465517328324856), ('travel', 0.024230473347417843), ('slant', 0.022500188846146546), ('act', -0.021414684767187876), ('earth', -0.015154773122041174)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('excellent', 0.09699819280987826), ('act', -0.06622263204063696), ('concept', -0.02283382438473685), ('get', -0.015523156798660512), ('to', -0.015485094128682438), ('watch', 0.01415092135936013), ('horror', -0.013421678588812429), ('day', 0.011013822435209432), ('slant', 0.00943366298128559), ('good', 0.009282808930053425)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('excellent', 0.08974621612359922), ('good', 0.07137733710584808), ('fun', 0.07086712290817831), ('different', 0.0654153978360225), ('concept', -0.02481507431501257), ('choose', -0.02419972967680293), ('slant', 0.023230880702919808), ('horror', 0.01967261336516237), ('film', 0.018879379068680122), ('to', 0.018407497127847287)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('story', 0.06784095726155526), ('just', 0.04916741308062682), ('gives', 0.047503117139577694), ('it', 0.04750311713957768), ('is', -0.029940382888300362), ('acting', 0.02141220904793533), ('to', 0.021412209047935327), ('one', -0.014319237454345593), ('day', -0.011266838707371912), ('but', -0.011266838707371909)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('got', 0.0006708305462824535), ('is', 0.0006708305462824532), ('more', 0.0006708305462824531), ('earth', 0.0006708305462824531), ('travel', 0.0005987651844792488), ('having', 0.0005987651844792488), ('out', 0.0005379852937979783), ('was', 0.0005379852937979779), ('an', 0.0005278019690099102), ('who', 0.00042220684937753234)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 34509
#
# True rating 0
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('solid', 0.04101066073405117), ('steer', -0.04049393348701734), ('kill', -0.03895132852537803), ('environment', 0.03839239147354038), ('enjoyable', 0.03605134848289037), ('era', 0.02818600012191863), ('weakness', 0.028167235809930594), ('direction', -0.023396438916688696), ('sign', -0.020226946307443365), ('reality', 0.019881479758889393)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('far', -0.06261086080509139), ('kill', -0.04205854391255222), ('interest', -0.041709391530218846), ('enjoyable', 0.038273335308037455), ('direction', -0.03269761292250978), ('sign', -0.01922898305104314), ('soft', -0.018739436372073655), ('problem', -0.01855152979081651), ('want', -0.017699891997191252), ('well', 0.015466034161069777)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('reality', 0.30529108659489496), ('enjoyable', 0.27202208111727694), ('solid', 0.2257735143045937), ('interest', -0.17895864689851199), ('entertainment', 0.1469090366739483), ('environment', -0.12808424932331264), ('dangerous', -0.06791931393412659), ('dog', -0.06538988535481778), ('kill', -0.06413047362333797), ('far', -0.057300387583086455)]
#
# Transformer_genetal - off the shelf
#
# Top contributing words for this prediction:
# [('well', 0.18313881202789228), ('all', 0.16995237053306128), ('entertainment', 0.08038440632598101), ('will', -0.03477475465070457), ('be', -0.023250868332284937), ('showing', -0.023250868332284937), ('light', -0.023250868332284916), ('want', -0.023250868332284916), ('problem', -0.021399258198720378), ('kill', -0.021399258198720378)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('who', 0.09016583523328822), ('era', 0.071649591677696), ('The', 0.07111631225376616), ('want', -0.023681394132887806), ('become', -0.016760801779745628), ('showing', -0.016760801779745624), ('portrayed', -0.009553990744306656), ('acting', 0.0022887211997764337), ('mafia', 0.0022887211997764316), ('side', 0.0017554417758466)]

# %% [markdown]
# ### positive

# %%
filtered_data_pos = data_eval.loc[(data_eval['eval_true'] == 1) 
                            & (data_eval['NB'] == 0)
                            & (data_eval['RF'] == 0)
                            & (data_eval['LSTM'] == 0) 
                            & (data_eval['Trans_general'] == 0) 
                            & (data_eval['Trans_tuned'] == 0)
                           ]

# %%
filtered_data_pos.shape[0]
# Out:
# 60

# %%
# review_list_pos=filtered_data_pos.head(30).index.tolist()

# %%
review_list_pos=[15229, 15927, 16741, 13324, 21722, 43911, 22994, 45079, 20310, 17860, 47418, 24411, 39212, 14780, 24435, 18958, 45963, 42104, 21488, 18529, 18469, 17768, 43367, 18783]

# %%
# data_eval.loc[review_list_pos]

# %%
for i in review_list_pos:
    print("============================================================================================================\n")
    print("============================================================================================================\n")
    
    print("index:", i, "\n")
    print("True rating", data['label'][i], "\n")
    
    print("\nNaive Beyes\n")
    exp_nb_pos = explainer_nb.explain_instance(data['review_preproc'][i], pipe_nb.predict_proba, num_features=10);
#     exp_nb_pos.show_in_notebook(text=True)
    exp_nb_pos.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_pos_{i}_nb.html')
    print("Top contributing words for this prediction:")
    print(exp_nb_pos.as_list(label=1))
    
    print("\nRandom Forest\n")
    exp_rf_pos = explainer_rf.explain_instance(data['review_preproc'][i], pipe_rf.predict_proba, num_features=10)
#     exp_rf_pos.show_in_notebook(text=True)
    exp_rf_pos.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_pos_{i}_rf.html')
    print("Top contributing words for this prediction:")
    print(exp_rf_pos.as_list(label=1))

    print("\nLSTM\n")
    exp_lstm_pos = explainer_lstm.explain_instance(data['review_preproc'][i], predict_proba)
#     exp_lstm_pos.show_in_notebook(text=True)
    exp_lstm_pos.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_pos_{i}_lstm.html')
    print("Top contributing words for this prediction:")
    print(exp_lstm_pos.as_list(label=1))

    print("\nTransformer_general - off the shelf\n")
    exp_tr_gen_pos = explainer_tr_gen.explain_instance(data['text'][i], predict_fn_gen, num_samples=10)
#     exp_tr_gen_pos.show_in_notebook(text=True)
    exp_tr_gen_pos.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_pos_{i}_tr_gen.html')
    print("Top contributing words for this prediction:")
    print(exp_tr_gen_pos.as_list(label=1))

    print("\nTransformer tuned\n")
    exp_tr_tuned_pos = explainer_tr_tuned.explain_instance(data['text'][i], predict_fn_tuned, num_samples=10)
#     exp_tr_tuned_pos.show_in_notebook(text=True)
    exp_tr_tuned_pos.save_to_file(f'{OUTPUT_PATH}/{date_str}/{date_str}_{dt.now().strftime("%H-%M-%S")}_lime_explain_pos_{i}_tr_tuned.html')
    print("Top contributing words for this prediction:")
    print(exp_tr_tuned_pos.as_list(label=1))
    print("\n")
# Out:
# ============================================================================================================
#
# ============================================================================================================
#
# index: 15229
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('beautifully', 0.03637637635984152), ('sadness', 0.03362348983140079), ('journey', 0.028505238765086083), ('powerful', 0.027796534087283283), ('compelling', 0.019595451686112923), ('best', 0.01919398960963077), ('beautiful', 0.01736173695719454), ('david', 0.016642564762611337), ('spent', -0.015515832396339668), ('biblical', -0.015474930141355427)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('instead', -0.12575724897821666), ('best', 0.05396900432857424), ('also', 0.03825662989674541), ('kill', -0.03721945382500864), ('beautiful', 0.030944800396676773), ('powerful', 0.023129735265006217), ('make', -0.022176699312598948), ('could', -0.017527165450614224), ('act', -0.01649653206456123), ('movie', -0.013301543448275367)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('atmosphere', 0.08307500383930984), ('best', 0.07208399031779668), ('believable', 0.06820939878870055), ('ten', 0.05966964276420045), ('instead', -0.047095773727122967), ('beautiful', 0.04337856497611673), ('real', 0.03755496081903262), ('could', -0.036190898556897506), ('susan', -0.02809837790076798), ('woman', -0.024890937722657915)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('and', 0.01527369164879856), ('Susan', 0.015273691648798556), ('biblical', 0.015273691648798554), ('think', 0.015273691648798552), ('can', 0.01527369164879855), ('Uriah', 0.01527369164879855), ('about', 0.00716532011741847), ('larger', 0.007165320117418469), ('To', -0.0046111607646073), ('this', -0.0036226607651213168)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('Peck', 0.0015665595700860462), ('You', 0.0015665595700860458), ('than', 0.0015665595700860458), ('One', 0.0015665595700860458), ('me', 0.0015665595700860456), ('deep', 0.0015665595700860456), ('a', 0.0015665595700860453), ('Susan', 0.0003386129714180729), ('time', -0.00023453113149598308), ('movie', -3.2519298543583916e-05)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 15927
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('underrated', 0.04963722285458488), ('excellent', 0.03941003378861166), ('gabriel', -0.03326301221166452), ('love', 0.028254385265341513), ('masterpiece', 0.026305446043503183), ('fascist', 0.022843683851881805), ('accurate', 0.018396475968908938), ('special', -0.017717053438027798), ('spend', -0.015001207308454265), ('rome', -0.014229759499802938)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('excellent', 0.10037230452909744), ('love', 0.0554150092432046), ('plot', -0.051268342468038554), ('look', -0.03456556307694173), ('thing', -0.028139408484627072), ('enjoy', 0.0219782958424778), ('spend', -0.021036787795573712), ('director', -0.014637666319240671), ('re', -0.014587303876350878), ('direction', -0.012677577539489344)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('gabriel', -0.2835155149010186), ('rome', -0.2825067849445418), ('underrated', 0.25324963315984245), ('special', 0.24406744872236577), ('fascist', -0.2375602677273343), ('love', 0.2220923375478913), ('visit', -0.18120758282574792), ('simply', -0.178831283362043), ('excellent', 0.1693482802863498), ('director', -0.14390128669331026)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('get', 0.07839215311863405), ('production', 0.07839215311863398), ('actors', 0.07839215311863396), ('another', 0.07839215311863396), ('our', 0.07839215311863393), ('his', -0.019251187823271638), ('fanatic', -0.018467955184256896), ('masterpiece', -0.005137594536842938), ('Loren', -0.0012840436314928744), ('wants', -0.0010534615028566288)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('remember', 0.14711443330108373), ('my', 0.10055805589237618), ('Italian', 0.08875262354421318), ('this', 0.08590176584844623), ('plot', -0.049676108681973655), ('another', -0.0378706763338107), ('huge', -0.03787067633381068), ('night', -0.03787067633381067), ('Rome', -0.03787067633381067), ('husband', -0.0025124430803211855)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 16741
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('delightful', 0.03956740036958251), ('falk', 0.03381757694379313), ('love', 0.027386493758587965), ('today', 0.022674571592267583), ('paul', 0.022330323420647363), ('tear', 0.021672823106557337), ('bore', -0.0201372934332691), ('craft', 0.01930740637832114), ('touch', 0.018984912293391668), ('advice', -0.01480656585008263)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bore', -0.12837638735073778), ('love', 0.04967321334569729), ('great', 0.048569592691342325), ('touch', 0.029831204519947297), ('guy', -0.029109229627702054), ('look', -0.02335730883282575), ('reiser', 0.019666136518698443), ('enjoy', 0.01782634268385393), ('delightful', 0.016748374163925068), ('fun', 0.012903054692227073)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('delightful', 0.008730084097444328), ('today', 0.0077757632910992434), ('bore', -0.007228308750924912), ('love', 0.006512018338836298), ('true', 0.0063082397042867), ('sometime', 0.005982662698236621), ('enjoy', 0.005757175109971969), ('everyone', 0.005736545666959603), ('theater', -0.0014326129747080757), ('falk', -0.0012348974118588298)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('father', 0.0005869891803954372), ('the', 0.00047813580206951023), ('around', 0.00046497868407364024), ('true', 0.0003385747955343921), ('really', -0.0002473163420964279), ('study', -1.3429136854215981e-05), ('watching', -1.3429136854215978e-05), ('be', -1.3429136854215976e-05), ('everyone', -1.342913685421597e-05), ('what', -2.7201885834606395e-07)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('Falk', 0.028828022920171052), ('Paul', 0.024741928418571927), ('study', 0.021565933755450847), ('true', 0.01639879896274386), ('edge', 0.01543234638877518), ('father', -0.015174651739941515), ('laugh', -0.013282825711532463), ('find', -0.0038175768450681873), ('the', 0.003702926439338171), ('fun', -0.002748376988080839)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 13324
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('brosnan', 0.06367672898208274), ('edge', 0.030761196301366728), ('oh', -0.028804400163007254), ('marvellous', 0.027488225576683213), ('kinnear', 0.026576167102233896), ('awesome', 0.020963699365009792), ('davis', 0.01998900581397961), ('bond', 0.01951794182396054), ('fun', 0.01874686090580912), ('businessman', 0.013619208534625242)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('oh', -0.11460508196807724), ('this', -0.04508167295453815), ('fun', 0.03871316024877229), ('kill', -0.03436863862101211), ('off', -0.03162306184726198), ('brosnan', 0.03159664169293759), ('could', -0.02542179285212448), ('movie', -0.02489606725573739), ('line', -0.01801495924025588), ('positive', -0.016456801284908437)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('fun', 0.36813492386251817), ('positive', -0.1668541478564131), ('pierce', -0.09457901046691843), ('with', -0.08417984944464163), ('edge', 0.07546885719043823), ('storyline', -0.06677432146387571), ('audience', 0.0617909244626346), ('intelligent', 0.06163182384149429), ('frantic', 0.05771221848883498), ('oh', -0.05374357024166239)]
#
# Transformer_general - off the shelf
# Top contributing words for this prediction:
# [('have', 0.08763547269542278), ('In', -0.020970239297263146), ('lines', -0.017192208060555325), ('appear', -0.011651537073269517), ('matador', -0.009140458791276434), ('she', -0.006709781345103971), ('gun', 0.005082724731806101), ('ending', -0.004980387902151377), ('could', 0.004440104955584974), ('been', -0.003896363012892627)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('cavil', 0.004190411497329372), ('suave', 0.0038761532029821656), ('frantic', 0.0031838885333374365), ('Davis', 0.002523823577547664), ('that', -0.0018948434396794916), ('harried', -0.0018523570937392698), ('plays', 0.001758567288710901), ('and', 0.000979936646869794), ('which', 0.0006708876407130404), ('dapper', -9.436864812372417e-05)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 21722
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('amaze', 0.02964041252440999), ('great', 0.026257380866443414), ('kudos', 0.025690791835354596), ('smoothly', 0.022432286227217272), ('beautiful', 0.020059676536940175), ('witty', 0.019664960358307497), ('europe', 0.01775182190051688), ('timing', 0.015387446873095898), ('accurate', 0.01387887747571438), ('target', -0.011016693677865808)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('plot', -0.06661290754737294), ('great', 0.06630684791630813), ('less', -0.02099432393415979), ('different', 0.02093997077891404), ('series', 0.02075888129697126), ('beautiful', 0.01950294902629589), ('line', -0.016295627100722514), ('author', -0.014870718372689275), ('thing', -0.013963816349209426), ('usa', 0.010983554374475941)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('great', 0.003683806869241724), ('amaze', 0.0029492233329361677), ('time', 0.0026739198439001523), ('beautiful', 0.0025577535118129816), ('witty', 0.002492460291661014), ('author', -0.0024782185365024505), ('mix', 0.002470919407105704), ('smoothly', 0.002397231102313773), ('different', 0.002086941053823945), ('kudos', 0.0020727266725874614)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('entertaining', 0.00011748446995199316), ('cast', 0.00010411554468980871), ('always', 7.284213737218962e-05), ('be', 7.28421373721896e-05), ('witty', 5.947321211000505e-05), ('well', 3.201257623377036e-05), ('done', 3.2012576233770346e-05), ('showed', -2.598116544188631e-05), ('less', -1.0735705186605534e-05), ('Kudos', -9.371873199899513e-06)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('that', 0.03451193628887609), ('comedy', 0.023515104079751672), ('dealing', 0.0190215959472712), ('Watching', -0.009648509251011872), ('going', -0.008602324851981575), ('than', -0.00568632242299796), ('smart', 0.005310509786126439), ('target', -0.0031933849311700535), ('in', -0.0023701640868488533), ('plot', -0.0022075675053330373)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 43911
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('everyday', 0.028338665783330982), ('rare', 0.0279197072232587), ('love', 0.023708094048074214), ('lovely', 0.023012178849769156), ('pray', -0.021721414318728788), ('grandfather', 0.02073593296467248), ('anne', 0.02055245340252967), ('annoy', -0.017343561849939248), ('swear', -0.007186292941209855), ('minute', -0.005919672599518593)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('annoy', -0.10528038475210637), ('love', 0.06253285639047591), ('minute', -0.04136117320796796), ('sally', 0.03031241786340533), ('enjoy', 0.029407522441159833), ('try', -0.021425607109323754), ('something', -0.0212085401170144), ('someone', -0.015975050910120327), ('movie', -0.011392973073636115), ('enough', -0.004867626984845429)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('rare', 0.007363341735288259), ('enjoy', 0.006764518648811482), ('collection', 0.006085717043330613), ('everyday', 0.006023183402141642), ('middle', 0.005401922196022221), ('lovely', 0.005394663076068317), ('anne', 0.005201065083335269), ('annoy', -0.0033873568079947304), ('enough', -0.0025649242402421366), ('minute', -0.001694611618724956)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('charming', 0.0004228578911328404), ('so', 0.0003048579327725692), ('she', 0.0003041163357380115), ('Moyne', 0.0003041163357380114), ('of', 0.0002461053327145025), ('someone', 0.00010775714931427249), ('up', 0.00010775714931427246), ('huge', 5.4368977250316645e-05), ('your', 4.974614629076386e-05), ('Should', -4.383622807749941e-06)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('and', 0.00027926134646320556), ('selfish', 0.00027692145508314555), ('lovely', 0.0002317746671476635), ('age', 0.00022639573934215385), ('story', 0.00022217316935689983), ('basis', 0.00022217316935689978), ('out', 0.00022075704033924998), ('This', 0.00017080061357751917), ('long', 0.0001179350064564676), ('prays', 6.740929071547607e-05)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 22994
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('horrendous', -0.04989946527902017), ('masterful', 0.03823483447819374), ('brilliant', 0.03503801707235735), ('provoke', 0.031024616391784138), ('flat', -0.029744001198284326), ('outlook', 0.028552611020563216), ('streep', 0.028221172957886984), ('tear', 0.027044221596910674), ('true', 0.02437595999815159), ('inspire', 0.023882040631501292)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('nothing', -0.11373432394692036), ('brilliant', 0.07897600443245775), ('flat', -0.05280853528196914), ('true', 0.03499779720662723), ('world', 0.032429629580712015), ('life', 0.02815378621694739), ('bring', 0.026883685145986335), ('less', -0.016262744164860538), ('direction', -0.014820719103551152), ('result', -0.013087706612714063)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('also', 0.0293995061199724), ('haunt', 0.026607073092750268), ('provoke', 0.023593010073263303), ('concept', -0.01582744795860929), ('nothing', -0.015660194553867603), ('true', 0.014338713972701369), ('tear', 0.013307371175869461), ('case', -0.005828622206423814), ('less', -0.005478117065043367), ('accurate', -0.003903825450138598)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('accurate', 0.20660498592111573), ('seeing', 0.18615210408275976), ('true', 0.12892084230582834), ('horrific', 0.11623004418526779), ('baffeling', 0.08934228278554696), ('brought', 0.06888940094719119), ('Streep', -0.05850815820297822), ('result', 0.04744809707868563), ('being', 0.04744809707868562), ('on', 0.03327241111564546)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('true', 0.03397646299702856), ('taken', 0.027090546609514474), ('being', 0.02582223734787126), ('witnessed', 0.024637590572338053), ('while', 0.023942871102500606), ('case', 0.015788645453343318), ('though', -0.01565119902039883), ('around', -0.013436132189138706), ('then', -0.007004860990472228), ('old', -0.005736551728829017)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 45079
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('everyday', 0.04681159900065759), ('nana', 0.042149534338250846), ('slow', -0.041817918806022175), ('talk', -0.035321818646515145), ('reminds', 0.030500420800487177), ('pbs', 0.029433250684087517), ('sleep', -0.02540461510744587), ('definitely', 0.025393723334948482), ('instead', -0.023941458258168905), ('grandma', -0.01493635713785556)]
#
# Random Forest
# Top contributing words for this prediction:
# [('instead', -0.14509964738105022), ('love', 0.07675070661633095), ('slow', -0.04816081728037081), ('would', -0.047473989740766775), ('care', -0.030439449400942196), ('read', -0.02673755269609013), ('definitely', 0.025257906996121265), ('sleep', -0.023595083989368604), ('book', -0.022258261229784856), ('can', -0.017129141990414758)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('slow', -0.5253990477778812), ('instead', -0.2533236422965638), ('sleep', -0.2025867177395389), ('everyday', 0.18844567143495355), ('love', 0.17662388323493725), ('definitely', 0.1656318799309274), ('book', -0.15871516765594743), ('reminds', 0.11807337387033433), ('talk', -0.09415435802747765), ('would', -0.08569807976896322)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('my', 0.08384945329041532), ('love', 0.07315545538395023), ('definitely', 0.07315545538395023), ('one', 0.0724635209723234), ('story', -0.03743440113085977), ('another', 0.03156176225737782), ('recommend', 0.031561762257377814), ('Mona', 0.020867764350912775), ('page', 0.02086776435091277), ('in', -0.014389600456219348)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('It', 0.030010216089087025), ('or', 0.030010216089087022), ('My', 0.02393316623739675), ('can', 0.023933166237396743), ('page', 0.011651740517579003), ('it', 0.011480024964304725), ('talking', 0.011480024964304716), ('read', 0.006102754508805457), ('book', 0.005574690665888722), ('instead', 0.005574690665888722)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 20310
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('capture', 0.05463004645218988), ('zombie', -0.03806444926538542), ('rent', -0.03676532707532222), ('amaze', 0.0356413221396713), ('urban', 0.023318520378628842), ('release', 0.021121770335996447), ('guy', -0.02013545231496392), ('hood', 0.01751257213408663), ('project', -0.014739247320615434), ('computer', -0.012301220772892607)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('amaze', 0.06063087809958039), ('also', 0.0515879286008466), ('zombie', -0.03349844561213045), ('good', 0.02418196901550864), ('time', 0.02176936857605704), ('pretty', -0.017347114997321514), ('look', -0.015129400393325394), ('project', -0.014706506714882479), ('rent', -0.014507964268181541), ('guy', -0.012207883543528947)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('bench', 0.15993235521811747), ('good', 0.10471474068112278), ('notice', 0.07975231015611146), ('occasion', -0.07344298638036126), ('project', -0.07075154163220267), ('capture', 0.07066634137107523), ('st', -0.0647873553164081), ('time', 0.061294020462203204), ('also', 0.05800019216200513), ('guy', 0.05509729315379269)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('ZoMbIeS', 0.14315622861985633), ('believe', 0.12824244799269208), ('funny', 0.09467608324096298), ('several', 0.09467608324096295), ('moment', 0.09467608324096294), ('if', 0.09418673911484615), ('near', -0.08823683024683146), ('computer', -0.08246934536239381), ('cast', 0.060620374363116986), ('how', 0.03785310722390864)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('believe', 0.08882715742306477), ('mind', 0.08882715742306475), ('lost', 0.08882715742306473), ('film', 0.061389967963338704), ('many', 0.05673850724498845), ('t', 0.05673850724498843), ('not', -0.03905971824198586), ('Patch', 0.03196649846916664), ('the', 0.031468512994025505), ('at', -0.0002135302284059627)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 17860
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('silk', -0.048261345488949496), ('disappointment', -0.042672891843490275), ('joy', 0.02860465302324932), ('lovely', 0.02638712772131723), ('dance', 0.024817503437306376), ('garbo', 0.02362790621572424), ('enjoyable', 0.02353770209000482), ('song', 0.02329300495263983), ('cole', 0.02284740347324267), ('douglas', 0.018830634127244474)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('silk', 0.07351915574648255), ('disappointment', -0.06495556784084365), ('enjoyable', 0.05264830166337165), ('experience', 0.03224600176755732), ('pure', 0.024779741066545517), ('dance', 0.02323476871464413), ('simple', 0.02051117401711539), ('less', -0.012143593628685471), ('make', -0.011727486389935362), ('whole', -0.010086396212339149)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('enjoyable', 0.39701631294242506), ('disappointment', -0.3715141960631063), ('whole', 0.22891738903583927), ('active', 0.1666067909913181), ('passive', 0.16230423747856365), ('short', 0.12388968194895078), ('ill', -0.10531620294476303), ('accident', -0.059043519625293236), ('joy', -0.05622156828556134), ('feature', -0.0469419053181997)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('ran', -0.16570690806015617), ('ill', -0.10392363237095849), ('be', -0.10392363237095847), ('This', -0.1039236323709584), ('will', 0.09082832093862966), ('short', -0.05520509274093451), ('experience', 0.02406799212958334), ('Lorre', -0.021839294850079023), ('joy', -0.019673494380592), ('by', 0.0065781829482633525)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('short', 0.06930358825174097), ('pure', 0.06282057158779304), ('should', -0.046382152639982445), ('joy', 0.04096854434307241), ('thing', 0.0409685443430724), ('lot', -0.035792629188890125), ('dances', 0.03280200065333917), ('Cyd', 0.03280200065333917), ('on', 0.030377596583773647), ('making', 0.002392485435297034)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 47418
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('release', 0.06169424956513686), ('original', -0.05690428004246719), ('prince', 0.029967471410343963), ('destiny', 0.02766591419768132), ('point', -0.02691834163292256), ('oz', 0.025225157013622178), ('only', -0.023142776008927113), ('song', 0.01997155191831913), ('chest', -0.01859807343985982), ('scream', -0.015523470612287071)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('point', -0.1050120560711424), ('original', -0.05511518312003011), ('third', -0.04722230921488561), ('dorothy', -0.027747984486245315), ('medium', -0.02285158241296976), ('heel', -0.019057340843437565), ('release', 0.016341507088324363), ('chest', -0.012161152278759005), ('man', 0.01076694898326101), ('mass', -0.009284519035151352)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('original', -0.2092675814246948), ('release', 0.13861032835179904), ('dorothy', -0.09474732741958998), ('electric', -0.08901060302378158), ('appearance', 0.0786579563468638), ('variety', 0.05076285112350037), ('scream', -0.046161017887911146), ('chest', -0.04317794529560996), ('raven', -0.042173166553581304), ('lion', -0.033104786077906644)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('br', 0.0009978732585555709), ('media', -0.0008464355905810846), ('synch', 0.000724480682374817), ('Sad', -0.0005685051853348068), ('For', -0.0005685051853348067), ('orchard', -0.0005426161116666336), ('other', 0.0003434970201799073), ('filmed', 0.00034349702017990723), ('score', 0.00030115202884848714), ('lion', -0.0001192874581403043)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('Dorothy', 0.010553954927287999), ('score', 0.010553954927287997), ('br', 0.010553954927287995), ('Wind', 0.010553954927287995), ('original', 0.010553954927287995), ('Faith', 0.010553954927287983), ('raven', 0.010260248152876607), ('For', 0.009809265672610977), ('is', 0.007923524906648865), ('Rocka', -0.005585392226570103)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 24411
#
# True rating 1
#
#
# Naive Beyes
# Top contributing words for this prediction:
# [('original', -0.07118722554312376), ('warmth', 0.06816813323492647), ('excellent', 0.06522011770753708), ('embarrass', -0.061315925532539), ('attempt', -0.049502697681486775), ('strong', 0.045838251258790146), ('drawback', 0.03499847814803209), ('unfortunately', -0.020227030635216962), ('sequel', -0.016232469510765554), ('lack', -0.015570109026198794)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('excellent', 0.0839402444466279), ('lack', -0.07482410660833107), ('attempt', -0.07185640836049109), ('embarrass', -0.0704542881384873), ('unfortunately', -0.03361064641857763), ('see', 0.028588545705080924), ('sequel', -0.026528038497264123), ('would', -0.019074255523420985), ('best', 0.018506126068308894), ('move', 0.016906224406119514)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('original', -0.49127196910073145), ('drawback', 0.26673414065053275), ('see', 0.23942572738198717), ('attempt', -0.16393403827979403), ('embarrass', -0.1451829653190195), ('best', 0.12571239032013562), ('excellent', 0.12034727095017972), ('flaw', 0.11800729531388983), ('unfortunately', -0.10439215880270485), ('lack', -0.09914786456788323)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('The', -0.16947967407244335), ('the', -0.1549710700393778), ('films', -0.1272029481334711), ('you', -0.10410641163082102), ('developed', -0.0965277561892517), ('he', 0.08651010620117845), ('t', -0.028718537620985356), ('provides', 0.02443233485686224), ('few', 0.006081003371374678), ('this', 0.0008041489893035735)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('thing', -0.08044218848990316), ('been', -0.06612319322077628), ('s', -0.05843271593378905), ('awkward', -0.04208440375927035), ('with', -0.04208440375927034), ('move', 0.03428614552566936), ('lives', 0.009780070925092537), ('he', 0.002789623568588542), ('an', -0.0020250862974603083), ('best', 0.0018149581694099257)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 39212
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('disappointed', -0.04644192751720562), ('dream', 0.030746889058320005), ('sit', -0.027250569619086885), ('cancel', 0.027109326992536306), ('true', 0.025097768887940373), ('surprise', 0.023432529397487977), ('tumble', 0.022787004379584166), ('vote', -0.02201138854019707), ('live', 0.01997142009440985), ('island', -0.014105535118843745)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('disappointed', -0.07399796192236574), ('that', -0.056541700579317684), ('sit', -0.05156756298564449), ('true', 0.04942371635593241), ('hard', -0.030006180831324527), ('it', 0.024832896833101074), ('other', 0.02392609151016738), ('cancel', 0.021221552523565793), ('them', -0.013927174172144861), ('much', -0.00987885500360615)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('disappointed', -0.6293019114744571), ('dream', 0.23676998047202458), ('read', -0.16494850190975083), ('surprise', 0.16110464950208708), ('true', 0.146086924840363), ('live', 0.13526998120020176), ('cancel', 0.1227010673133912), ('internet', 0.11945780487037524), ('hard', -0.11462327611581023), ('it', 0.10965089476112974)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('can', -0.031409417434346616), ('for', -0.031409417434346616), ('and', -0.03140941743434661), ('dreams', -0.02740716903142428), ('the', -0.02617335654021898), ('came', -0.025554897300809846), ('find', -0.025189811537100704), ('show', -0.022678114475905915), ('sat', 0.01434340372492658), ('island', 0.0023399747228959817)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('vote', 0.05935768435194431), ('there', 0.0593576843519443), ('down', 0.0332793085893161), ('next', 0.029298977723823394), ('dreams', 0.028387011823081315), ('worked', 0.028387011823081308), ('didn', 0.0283870118230813), ('they', 0.016987187392537857), ('other', 0.014005160543968916), ('disappointed', -0.012073215218659325)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 14780
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('lombard', -0.11909541481146459), ('kitty', 0.0350690484671774), ('best', 0.033662031625156526), ('barber', 0.032834822458617186), ('subtle', 0.031761817251666574), ('forgettable', -0.030650076065252673), ('embarrassment', -0.007006065075475903), ('dull', -0.004178747010752808), ('mediocre', -0.003490595301723892), ('low', -0.0012425519721727606)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('lombard', 0.06622510311097125), ('best', 0.05881067456408755), ('dull', -0.04287773345646087), ('suppose', -0.04111022699063023), ('true', 0.039731915924910946), ('bore', -0.034305474869132345), ('even', -0.03382490959063235), ('act', -0.022820434756493466), ('low', -0.021785149714519572), ('forgettable', -0.01722831432986568)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('lombard', -0.7433135384358968), ('forgettable', -0.12174162167454226), ('humor', 0.110895599177448), ('effective', 0.07532642245696544), ('subtle', 0.06741527512462663), ('dull', -0.06147935331523579), ('rare', 0.05078587625051444), ('rather', -0.049395282013858816), ('trumpet', 0.04814080175960121), ('score', 0.039994630672537265)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('Pangborn', -0.17447733362831364), ('Skid', -0.17447733362831355), ('DAWN', -0.0857624693607492), ('a', -0.07811829945134835), ('humor', -0.07180369701904067), ('score', -0.07180369701904064), ('deal', -0.029059067678167745), ('if', -0.02905906767816773), ('at', -0.029059067678167728), ('though', 0.016911167248523776)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('Hart', -0.16896824659370066), ('constantly', -0.1671219868964752), ('an', -0.16023308231628283), ('jazz', -0.16018340287663424), ('dull', -0.12037372744839125), ('across', -0.09833316665249607), ('A', -0.06852477169401182), ('shortly', -0.06852477169401172), ('very', -0.02177651224592816), ('keep', -0.010315552240982524)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 24435
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('lds', -0.046199841568545286), ('fails', -0.04040962731380386), ('fascinate', 0.029106708520733174), ('treat', 0.028417304058802068), ('controversial', 0.027039636526430454), ('smith', 0.025014981359226533), ('marriage', 0.022933079127099566), ('educational', 0.02278829496432477), ('fail', -0.020476505023570887), ('insight', 0.018695890270419725)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('fail', -0.08931720066810996), ('great', 0.07673696095385772), ('fails', -0.06950560026549908), ('also', 0.051856088222252135), ('life', 0.04011957897253271), ('would', -0.03204918760718296), ('lds', 0.029791506047055376), ('view', 0.02133818866533382), ('idea', -0.0200216730758982), ('all', -0.00940846330712156)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('fail', -0.21797019286507027), ('president', -0.21782630177748746), ('fails', -0.18625761153534118), ('lds', -0.18532850019545016), ('prophet', 0.12239319943044018), ('maybe', -0.10771380480358829), ('fascinate', 0.09169949269375319), ('treat', 0.08751699182343382), ('statement', 0.07919517217093161), ('controversial', 0.07768563367864803)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('fails', -0.19914776155545114), ('was', -0.19914776155545108), ('been', -0.17689051007211243), ('ran', -0.1385123799228118), ('more', -0.0808206167808837), ('which', 0.03837187588837648), ('how', 0.03837187588837648), ('many', 0.03837187588837647), ('historians', 0.02903544091507348), ('format', 0.02903544091507344)]
#
# Transformer tuned
# Top contributing words for this prediction:
# [('is', -0.287197122168908), ('in', 0.15492033960936072), ('issue', 0.1486782983007116), ('been', 0.09885207243193186), ('have', 0.07516743071457915), ('all', 0.07242020279116351), ('to', 0.07010574283361512), ('Maybe', 0.06771968219402785), ('for', 0.05740821830431053), ('After', 0.039709129220643236)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 18958
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('awful', -0.06284525770339612), ('unattractive', -0.03956806165668459), ('hal', 0.030171507665312163), ('honestly', -0.028319112756715475), ('memorable', 0.027152434243269876), ('effective', 0.025816418266978513), ('short', 0.020911498071437256), ('great', 0.018887697274555866), ('precious', -0.011916841627679264), ('chubby', -0.010232791436113633)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('awful', -0.24160066245195494), ('great', 0.06580940688608224), ('even', -0.03713626492606834), ('job', 0.027925575063925127), ('well', 0.025249722156515438), ('call', -0.022406104559200016), ('plot', -0.016930152815973838), ('reason', -0.01426568341430424), ('honestly', -0.013381123282193276), ('year', 0.012316684274326759)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('great', 0.13646296804496613), ('hal', 0.11521960034112365), ('effective', 0.11049676105437928), ('chance', 0.09753137711024036), ('memorable', 0.08529718065219881), ('roach', -0.0851776423135106), ('awful', -0.0747159335986717), ('short', 0.0705838404053183), ('glad', 0.0534150291944569), ('crank', -0.04516453178215791)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('doing', 0.09206383425999817), ('written', 0.09206383425999815), ('plot', 0.09206383425999812), ('all', 0.07458695702527854), ('memorable', 0.030222304528644085), ('FINALLY', 0.03022230452864407), ('Spanky', 0.007942948706596512), ('for', 0.0058826334150316175), ('unattractive', -0.0033671560023713796), ('pretty', 0.001195907756646236)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('from', 0.005462303379825025), ('later', 0.005462303379825024), ('on', 0.0045653203682433), ('tiny', -0.003597557959158726), ('murder', 0.002782377931956378), ('decades', -0.002209744288653464), ('just', -0.0021730281599138396), ('call', -0.0010583068165865355), ('boy', 0.000950240434791273), ('think', -0.0002088663770131164)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 45963
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('horrible', -0.06783530036777739), ('stupid', -0.05396408849708027), ('money', -0.03605808330204052), ('amazing', 0.035141689726115935), ('obviously', -0.03352984626215933), ('lack', -0.026726549444574425), ('today', 0.023506398776203884), ('hilarious', 0.016037637190446007), ('era', 0.014225047096033849), ('humorous', 0.010650259547533968)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('horrible', -0.10005435425432678), ('stupid', -0.04780080474311998), ('enjoy', 0.03594219761657289), ('make', -0.0358296094545288), ('today', 0.030848122862790782), ('half', -0.02757389887009122), ('anything', -0.02392101114732451), ('money', -0.021557886356824322), ('act', -0.020870449454239496), ('hilarious', 0.02052909434138397)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('horrible', -0.35580677993807647), ('hilarious', 0.3233090198069418), ('half', -0.19710069076952724), ('enjoy', 0.15220161825060954), ('amazing', 0.14938311360853268), ('humor', 0.1438093323221134), ('lack', -0.13860459451380527), ('today', 0.1376282761503975), ('act', -0.1234769824171692), ('money', -0.1230088416805463)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('it', 0.1184138815728194), ('era', 0.1184138815728194), ('to', 0.11633709737207522), ('makes', 0.11633709737207522), ('amazing', 0.0988320726012397), ('brain', 0.09883207260123969), ('exploitation', 0.09883207260123962), ('there', 0.07015890278286598), ('they', 0.07015890278286598), ('with', 0.07015890278286595)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('of', 0.12248395166767971), ('WAY', 0.12248395166767964), ('was', 0.09131469097458765), ('up', 0.07298305819669759), ('dare', 0.06443537820062537), ('hour', 0.06443537820062534), ('you', 0.06443537820062532), ('The', 0.06443537820062532), ('style', 0.06443537820062531), ('watching', 0.06443537820062528)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 42104
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('awesome', 0.09102088077287777), ('plain', -0.06317915455138445), ('money', -0.0567690860519744), ('low', -0.04050144843279122), ('love', 0.037930215161690636), ('pay', -0.034400509834269025), ('budget', -0.0292490906738179), ('scary', -0.02537287708821945), ('act', -0.016671962768986723), ('simply', -0.012204511149252669)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('money', -0.11260278909236922), ('love', 0.11020639384912449), ('low', -0.08671913363212871), ('act', -0.08089525789260145), ('pay', -0.05343378806117578), ('movie', -0.035576165203448425), ('awesome', 0.02431950279020886), ('budget', -0.02385720100756639), ('plain', -0.02251991784580897), ('woman', 0.016548138652184036)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('money', -0.5057403937302191), ('low', -0.275477351928203), ('worth', 0.2384278130883815), ('awesome', 0.2360732718469513), ('blockbuster', -0.15969245667291881), ('hot', 0.14975730692246794), ('woman', -0.14262349686396097), ('love', 0.1364089046057161), ('good', 0.11113323844322778), ('for', -0.10417003179890767)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('out', 0.011808526455311207), ('but', 0.007489964156794825), ('worth', 0.00684368398063915), ('plain', -0.005939411759584279), ('very', 0.0025251216821227753), ('for', 0.002204846693900817), ('be', -0.0017405203147733675), ('and', 0.0015793994007962113), ('simply', -0.00038780957681199647), ('to', 0.00037814145304913935)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('acting', 0.11460896044212378), ('some', 0.1117651834570733), ('was', 0.09054906348946716), ('low', 0.055470081661838214), ('loved', 0.05547008166183819), ('scary', 0.055470081661838165), ('hot', 0.034253961694231956), ('turned', -0.033948791358512656), ('movie', -0.017797549754747816), ('out', -0.002763795187557172)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 21488
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('suck', -0.053602876468847906), ('magnificent', 0.039380550097759155), ('billy', 0.03879146557485305), ('bully', 0.03262977262516195), ('ok', -0.031605225710378534), ('disappointed', -0.030055139406872797), ('weak', -0.02981758512612334), ('bad', -0.02979899461840596), ('bet', -0.02890358059437444), ('family', 0.024042094539715494)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('bad', -0.1375054380950187), ('nothing', -0.08206359442401713), ('suck', -0.03993054599930069), ('family', 0.0376886809420768), ('plot', -0.02828422169379117), ('act', -0.02430189428725598), ('weak', -0.022770946285222367), ('movie', -0.020595577051233268), ('ok', -0.018969483383446492), ('els', -0.011797349991569417)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('weak', -0.34972900885688984), ('good', 0.277241116610707), ('bully', 0.2101233649243108), ('nothing', -0.2075149197641093), ('bad', -0.1568390182113017), ('disappointed', -0.15108670150740305), ('magnificent', 0.12241823360107268), ('suck', -0.11819883638789083), ('book', -0.09251567683003985), ('apocalypse', 0.08824426019435624)]
#
# Transformer_general - off the shelf
# Top contributing words for this prediction:
# [('expecting', -0.16456125669157934), ('think', -0.16456125669157926), ('He', -0.153720875769445), ('eat', 0.12699562998077776), ('as', 0.12699562998077774), ('the', 0.10216197794769015), ('some', 0.10085217163497785), ('plot', 0.09969360991404949), ('I', 0.040484844410582144), ('nothing', 0.02938461280785239)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('7', 0.20837058600922698), ('exaggerate', 0.1769653032449446), ('OK', 0.10633877727793167), ('kid', 0.10048999886765655), ('because', -0.03669548684641019), ('able', -0.036695486846410184), ('I', -0.02569291310084337), ('elementary', -0.02569291310084337), ('not', -0.025692913100843363), ('family', -0.025692913100843352)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 18529
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('fun', 0.14476821836714926), ('suppose', -0.05689670793754915), ('slasher', -0.041294431952396966), ('plot', -0.04096462066221841), ('surprisingly', 0.03948876809266658), ('brain', -0.032507405208728433), ('creative', 0.026753561768882026), ('rest', -0.02045193104741994), ('actually', -0.019603621749564225), ('music', 0.018229679057646424)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('suppose', -0.15910475127871712), ('plot', -0.13310243236601074), ('would', -0.07361817282259574), ('act', -0.044222529144795714), ('actually', -0.04122814958359644), ('fun', 0.0383885694094463), ('good', 0.03459848906439024), ('slasher', -0.019408752946099995), ('music', 0.016408669382778615), ('surprisingly', 0.008113497193719883)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('fun', 0.5975281629226352), ('creative', 0.2372730015393939), ('brain', -0.11037160235839744), ('rest', -0.10226009154617315), ('bloody', 0.09252661935128265), ('suppose', -0.089864886600462), ('good', 0.08906349204442794), ('compare', 0.08652320845568116), ('slasher', -0.05954545379934001), ('find', -0.05919643097181454)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('a', 0.13121071847945553), ('it', 0.1312107184794555), ('this', 0.13121071847945548), ('the', 0.0979258309502689), ('plot', 0.08786064981032571), ('to', 0.0878606498103257), ('of', 0.0599425112686741), ('some', 0.05994251126867409), ('music', -0.04471796570321014), ('not', -0.011485579914293425)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('plot', 0.014944381394630262), ('fun', 0.012333798044108736), ('Surprisingly', 0.011508774633544435), ('very', 0.01131398694899232), ('deserve', 0.011131333444779094), ('The', -0.010941668547609026), ('10', 0.008675175886772314), ('This', 0.008480388202220204), ('supposed', -0.0031176355899564553), ('creative', 0.0011043117471579505)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 18469
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('terrible', -0.07225846114418397), ('batman', 0.06944927551184356), ('sorry', -0.04496097198348519), ('oh', -0.0390422880973356), ('unfortunately', -0.034394281310555656), ('great', 0.03438620136776129), ('joke', -0.028817306692811732), ('solid', 0.02778797784586587), ('more', 0.01864429628358242), ('trapping', 0.012282625309792884)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('terrible', -0.1373378602978476), ('great', 0.13436780269201232), ('sorry', -0.039028764671829023), ('oh', -0.036412919577442845), ('unfortunately', -0.03359195730355149), ('seem', -0.025921499867037727), ('job', 0.025146481829529686), ('see', 0.023392821478661806), ('entertain', 0.021948028347244516), ('movie', -0.021211288632259895)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('great', 0.34327017350283795), ('sorry', -0.28271050111586005), ('more', 0.259686810261222), ('entertain', 0.25281490470211065), ('solid', 0.22168370293666992), ('trapping', 0.21100951523347547), ('seem', -0.20943716259029813), ('oh', -0.1997725533264607), ('unfortunately', -0.17451980230615002), ('hate', -0.1388084488673119)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('out', -0.12665133958067856), ('I', -0.11425591514019397), ('want', -0.10457251399497117), ('The', -0.10086325766803543), ('more', -0.08723382916098248), ('left', -0.08541198246234016), ('t', -0.08541198246234014), ('hated', -0.07737988940740045), ('great', 0.07534076686786689), ('but', -0.018143803306954146)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('s', -0.08060607436360362), ('think', -0.03760194467240565), ('Oh', -0.036769568852140465), ('wanting', -0.036769568852140465), ('Unfortunately', 0.026978484657944096), ('joke', 0.025868411153502517), ('all', -0.01796809435796058), ('left', 0.012683683680575934), ('out', 0.01185130786031077), ('Superman', 0.007826805280945637)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 17768
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('complex', 0.0444972578273259), ('lampoon', -0.028563592768673977), ('orient', 0.02421401460641269), ('novella', 0.023739241787192278), ('wrestler', -0.022081432723315166), ('wrestle', -0.0215791146895264), ('target', -0.017859355530856876), ('arnie', -0.017662265381816998), ('none', -0.0165417019956385), ('arnold', -0.0158485238237016)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('half', -0.08169316150278368), ('novella', 0.04139702308621485), ('complex', 0.03737510064141444), ('pro', 0.036728230087534494), ('well', 0.02938260906115098), ('liner', 0.02925844333914847), ('less', -0.011670132776584432), ('far', -0.0030512391019159274), ('run', -0.001044217035138376), ('thing', -0.0007151610739407719)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('complex', 0.2691928476205578), ('choreograph', 0.19936842024224868), ('none', -0.12868976522343395), ('require', 0.12090748133013741), ('flick', 0.09647706752004935), ('far', -0.08716040792558429), ('liner', 0.07448254340584233), ('basically', -0.07442589036332857), ('well', 0.06603780617704813), ('government', 0.06589971536194852)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('Arnie', -0.06980497774844106), ('entertainment', -0.0653727672882134), ('sequences', -0.024181523433256673), ('Man', -0.02047621390115481), ('on', -0.011056954993254355), ('basically', 0.009036016914658034), ('wrestling', 0.008863612446779983), ('It', 0.008744948127951022), ('network', 0.0037547461923128547), ('none', 0.0037547461923128486)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('basically', 0.01033059818513322), ('far', 0.010330598185133218), ('it', 0.007765962032941576), ('on', 0.006918932042933501), ('Man', 0.006624777428066129), ('way', 0.006212097926834081), ('flick', 0.006212097926834078), ('oriented', 0.006212097926834075), ('an', -0.0010159292474549953), ('action', 7.222920976545547e-05)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 43367
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('elementary', -0.0495929645036668), ('solid', 0.025726189335751454), ('premise', -0.02365088988544666), ('rome', -0.019344350579495947), ('indicate', -0.018437464889808245), ('scientific', -0.017410959798411254), ('satisfy', 0.014751098535607311), ('understanding', 0.013306877629013336), ('civilization', 0.012971507021395028), ('popular', 0.011168821094697802)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('even', -0.1015637927764234), ('least', -0.0612534457441458), ('different', 0.04286714585927722), ('life', 0.03435454968652919), ('make', -0.028742713213573273), ('science', -0.026590570443570404), ('seem', -0.022176543134566774), ('enough', -0.012844423391526465), ('admittedly', -0.012760347922310147), ('replace', -0.01190888727802083)]
#
# LSTM
# Top contributing words for this prediction:
# [('rome', -0.1076027134192217), ('fiddle', -0.1060550170984519), ('elementary', -0.09548965531327493), ('least', -0.07906509930232812), ('solid', 0.07727787458644216), ('different', 0.06195212474136868), ('admittedly', -0.06172967355466379), ('book', -0.0515771228972395), ('not', -0.0490844014892028), ('depend', 0.04596225226103147)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('film', -0.07067570412851017), ('to', -0.06666975062714628), ('solid', 0.05575088353494787), ('replace', -0.04106034232732025), ('do', -0.04106034232732023), ('I', -0.03739573338491712), ('must', -0.03637005617096716), ('resources', -0.02688684399591743), ('while', 0.025451189078768782), ('stuff', -0.013132285004901637)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('the', 0.18877962321056455), ('textbook', 0.13531834592923414), ('commentators', 0.11586497762032924), ('Diamond', 0.07112106417003233), ('Science', 0.05670594968310401), ('cannot', 0.056705949683103954), ('which', -0.05228679893996849), ('different', 0.024751846859187805), ('only', 0.022046623850780597), ('civilizations', 0.02204662385078053)]
#
#
# ============================================================================================================
#
# ============================================================================================================
#
# index: 18783
#
# True rating 1
#
#
# Naive Beyes
#
# Top contributing words for this prediction:
# [('badly', -0.048220546634499706), ('dull', -0.04383583158096918), ('bother', -0.03625975992966887), ('cgi', -0.03339511819208206), ('animate', 0.0283212437110762), ('disney', 0.01991731661899858), ('atlantis', 0.016683712414564702), ('traditional', 0.01648935815781304), ('artistry', 0.015504442001414542), ('beauty', 0.01367546065576185)]
#
# Random Forest
#
# Top contributing words for this prediction:
# [('dull', -0.10469494793879884), ('bother', -0.06596798722312258), ('badly', -0.06194092610896565), ('best', 0.04225522147457477), ('also', 0.03541505979133725), ('true', 0.02903560611293813), ('kill', -0.028184510695581425), ('plot', -0.025981119080616177), ('except', -0.020898480190938675), ('release', 0.020608924006925596)]
#
# LSTM
#
# Top contributing words for this prediction:
# [('method', -0.22997796256445063), ('inc', 0.21337305808290902), ('true', 0.20992807788527407), ('traditional', 0.20859573799386613), ('screw', -0.1572588144044603), ('death', 0.13974990185372652), ('dull', -0.11441873132054887), ('bother', -0.0834870037629511), ('maybe', -0.07197854894077957), ('rampant', -0.06383568193672944)]
#
# Transformer_general - off the shelf
#
# Top contributing words for this prediction:
# [('involves', 0.0005949352323230958), ('traditional', -0.0004942627477338436), ('shots', 0.00044030459129183963), ('fantasy', 0.0004119133678807025), ('five', -0.00030061729965777454), ('eye', 0.00019107856543023534), ('heard', 0.00016721148387081764), ('Beauty', 0.00016721148387081755), ('d', 0.00016721148387081755), ('it', 0.00016721148387081753)]
#
# Transformer tuned
#
# Top contributing words for this prediction:
# [('as', -0.1442577887674172), ('not', -0.14425778876741718), ('that', -0.14425778876741718), ('a', -0.10218772799323807), ('looked', -0.07702184106128462), ('critics', -0.054600299465755), ('some', -0.054600299465754995), ('Kids', -0.03248854014500629), ('what', -0.03248854014500627), ('hundred', -0.019553242974914068)]

# %%
data.loc[3618]# I'm not sure if this is the correct label???
# Out:
# text              Time travel is a fun concept, and this film gives it a different slant. I got a kick out of Captain Billingham, one of the more down-to-earth characters, who was just not having a good day. Ordinarily, I don't choose to watch horror films, but this is an exception. Good story, excellent acting.
# label             0
# review_preproc    time travel fun concept film give different slant get kick captain billingham one down to earth character good day ordinarily choose watch horror film exception good story excellent act
# Name: 3618, dtype: object
